# %%
from tqdm import tqdm
import numpy as np
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import os

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype(np.uint8)
x_test = x_test.astype(np.uint8)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
class PresentModified:
    SBOX = [0xc, 0x5, 0x6, 0x2, 0x9, 0x0, 0xa, 0xd,
            0x3, 0xe, 0xf, 0x8, 0x4, 0x7, 0x1, 0x2]
    PBOX = [0, 16, 32, 48, 1, 17, 33, 49,
            2, 18, 34, 50, 3, 19, 35, 51,
            4, 20, 36, 52, 5, 21, 37, 53,
            6, 22, 38, 54, 7, 23, 39, 55,
            8, 24, 40, 56, 9, 25, 41, 57,
            10, 26, 42, 58, 11, 27, 43, 59,
            12, 28, 44, 60, 13, 29, 45, 61,
            14, 30, 46, 62, 15, 31, 47, 63]

    def __init__(self, key: bytes, rounds: int = 32):
        self.rounds = rounds
        self.roundkeys = self._generate_roundkeys(int.from_bytes(key, 'big'))

    def _generate_roundkeys(self, key):
        roundkeys = []
        for i in range(1, self.rounds + 1):
            roundkeys.append(key >> 16)
            key = ((key & (2**19 - 1)) << 61) | (key >> 19)
            sbox_val = self.SBOX[key >> 76]
            key = (sbox_val << 76) | (key & (2**76 - 1))
            key ^= i << 15
        return roundkeys

    def _add_round_key(self, state, roundkey):
        return state ^ roundkey

    def _sbox_layer(self, state):
        output = 0
        for i in range(16):
            output |= self.SBOX[(state >> (i * 4)) & 0xF] << (i * 4)
        return output

    def _p_layer(self, state):
        output = 0
        for i in range(64):
            output |= ((state >> i) & 1) << self.PBOX[i]
        return output

    def encrypt(self, block: bytes) -> bytes:
        state = int.from_bytes(block, 'big')
        for i in range(self.rounds - 1):
            state = self._add_round_key(state, self.roundkeys[i])
            state = self._sbox_layer(state)
            state = self._p_layer(state)
        state = self._add_round_key(state, self.roundkeys[-1])
        return state.to_bytes(8, 'big')

# %%
def encrypt_image(img, cipher):
    encrypted = np.zeros_like(img)
    for ch in range(3):
        for row in range(0, 32, 8):
            for col in range(0, 32, 8):
                block = img[row:row+8, col:col+8, ch].flatten()
                for i in range(8):
                    row_bytes = block[i*8:(i+1)*8]
                    if len(row_bytes) < 8:
                        row_bytes = np.pad(row_bytes, (0, 8-len(row_bytes)), 'constant')
                    encrypted_block = cipher.encrypt(bytes(row_bytes))
                    encrypted[row+i, col:col+8, ch] = list(encrypted_block)
    return encrypted

# %%
import os
random_key = os.urandom(10)
cipher = PresentModified(key=random_key)

# %%
from tqdm import tqdm
x_train_encrypted = np.zeros_like(x_train)
for i in tqdm(range(len(x_train)), desc="Encrypting CIFAR-10"):
    x_train_encrypted[i] = encrypt_image(x_train[i], cipher)
# Out:
# Encrypting CIFAR-10: 100%|██████████| 50000/50000 [3:00:59<00:00,  4.60it/s]

# %%
np.save("x_train_encrypted.npy", x_train_encrypted)
np.save("y_train.npy", y_train)

# %%
np.save("/content/x_train_encrypted_present_mod.npy", x_train_encrypted)
np.save("/content/y_train.npy", y_train)

with open("/content/present_modified_key.bin", "wb") as f:
    f.write(random_key)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from PIL import Image
output_folder = "/content/drive/MyDrive/Present_cipher_project/encrypted_images"
os.makedirs(output_folder, exist_ok=True)
for i, img in enumerate(x_train_encrypted):
    img_uint8 = Image.fromarray(img.astype(np.uint8))
    img_uint8.save(os.path.join(output_folder, f"{i}.png"))

# %%
import shutil
import os

folder_to_zip = "/content/drive/MyDrive/Present_cipher_project"
zip_output_path = "/content/drive/MyDrive/Present_cipher_project.zip"

if os.path.exists(zip_output_path):
    os.remove(zip_output_path)

shutil.make_archive(base_name=zip_output_path.replace('.zip', ''),
                    format='zip',
                    root_dir=folder_to_zip)

print(f" Successfully created ZIP: {zip_output_path}")
# Out:
#  Successfully created ZIP: /content/drive/MyDrive/Present_cipher_project.zip

# %%
from google.colab import files
files.download("/content/drive/MyDrive/Present_cipher_project.zip")

# %%
import matplotlib.pyplot as plt
import random
num_images = 10
indices = random.sample(range(len(x_train_encrypted)), num_images)
plt.figure(figsize=(20, 4))

for i, idx in enumerate(indices):
    # Original image
    plt.subplot(2, num_images, i + 1)
    plt.imshow(x_train[idx])
    plt.title("Original")
    plt.axis('off')

    # Encrypted image
    plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(x_train_encrypted[idx])
    plt.title("Encrypted")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

encrypted_img_src = '/content/drive/MyDrive/Present_cipher_project/encrypted_images'
print("Exists:", os.path.exists(encrypted_img_src))
print("Is dir:", os.path.isdir(encrypted_img_src))
# Out:
# Exists: True
# Is dir: True

# %%
import zipfile
import os

# Paths
base_dir = "/content/drive/MyDrive/Present_cipher_project"
output_dir = "/content/present_buckets_raw"
os.makedirs(output_dir, exist_ok=True)

zip_map = {
    "present_original.zip": "class_0",
    "present_3to1_cipher.zip": "class_1",
    "present_3to5_cipher.zip": "class_2",
    "present_3to2_cipher.zip": "class_3",
}

# Extract all 4 zips
for zip_name, class_name in zip_map.items():
    zip_path = os.path.join(base_dir, zip_name)
    extract_path = os.path.join(output_dir, class_name)
    os.makedirs(extract_path, exist_ok=True)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

    print(f"Extracted {zip_name} to {extract_path}")
# Out:
# Extracted present_original.zip to /content/present_buckets_raw/class_0
# Extracted present_3to1_cipher.zip to /content/present_buckets_raw/class_1
# Extracted present_3to5_cipher.zip to /content/present_buckets_raw/class_2
# Extracted present_3to2_cipher.zip to /content/present_buckets_raw/class_3

# %%
for class_name in sorted(os.listdir(input_root)):
    class_path = os.path.join(input_root, class_name)
    images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
    print(f"{class_name}: {len(images)} images")
# Out:
# class_0: 50000 images
# class_1: 0 images
# class_2: 50000 images
# class_3: 4491 images

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"
extract_path = "/content/present_buckets_raw/class_1"

# Clear and re-extract
if os.path.exists(extract_path):
    shutil.rmtree(extract_path)
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Re-extracted class_1 from present_3to1_cipher.zip")
# Out:
# Re-extracted class_1 from present_3to1_cipher.zip

# %%
for class_name in sorted(os.listdir(input_root)):
    class_path = os.path.join(input_root, class_name)
    images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
    print(f"{class_name}: {len(images)} images")
# Out:
# class_0: 50000 images
# class_1: 0 images
# class_2: 50000 images
# class_3: 4491 images

# %%
import shutil
shutil.rmtree("/content/present_buckets_raw/class_1", ignore_errors=True)

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"
extract_path = "/content/present_buckets_raw/class_1"

# Recreate folder
os.makedirs(extract_path, exist_ok=True)

# Extract
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(" Re-extracted class_1")
# Out:
#  Re-extracted class_1

# %%
class_path = "/content/present_buckets_raw/class_1"
images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
print(f"class_1 now has {len(images)} images")
# Out:
# class_1 now has 0 images

# %%
import zipfile
import shutil
import os

# Clear old class_1 folder (just in case)
extract_path = "/content/present_buckets_raw/class_1"
shutil.rmtree(extract_path, ignore_errors=True)
os.makedirs(extract_path, exist_ok=True)

# Re-extract from the re-uploaded ZIP
zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(" Re-extracted class_1 from the new ZIP")
# Out:
#  Re-extracted class_1 from the new ZIP

# %%
class_path = "/content/present_buckets_raw/class_1"
images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
print(f" class_1 now has {len(images)} images")
# Out:
#  class_1 now has 0 images

# %%
import zipfile

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    contents = zip_ref.namelist()
    print(f"📦 ZIP contains {len(contents)} entries")
    print("📁 Sample entries:", contents[:10])
# Out:
# 📦 ZIP contains 50001 entries
# 📁 Sample entries: ['encrypted_images/', 'encrypted_images/0.png', 'encrypted_images/1.png', 'encrypted_images/2.png', 'encrypted_images/3.png', 'encrypted_images/4.png', 'encrypted_images/5.png', 'encrypted_images/6.png', 'encrypted_images/7.png', 'encrypted_images/8.png']

# %%
import zipfile
import shutil
import os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"
extract_path = "/content/present_buckets_raw/class_1"

# Clear previous content
shutil.rmtree(extract_path, ignore_errors=True)
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    for member in zip_ref.namelist():
        if member.endswith(".png"):
            # Get filename only (e.g., '0.png') even if it's inside 'encrypted_images/'
            filename = os.path.basename(member)
            if not filename:
                continue
            source = zip_ref.open(member)
            target = open(os.path.join(extract_path, filename), "wb")
            with source, target:
                shutil.copyfileobj(source, target)

print(" Flattened extraction of class_1 completed.")
# Out:
#  Flattened extraction of class_1 completed.

# %%
class_path = "/content/present_buckets_raw/class_1"
images = [img for img in os.listdir(class_path) if img.endswith(".png")]
print(f" class_1 now has {len(images)} images")
# Out:
#  class_1 now has 50000 images

# %%
# Navigate to the folder and zip it
# !cd "/content/drive/MyDrive/Present_cipher_project" && zip -r present_3to2_cipher.zip encrypted_images
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: encrypted_images/4000.png (stored 0%)
#   adding: encrypted_images/4001.png (stored 0%)
#   adding: encrypted_images/4002.png (stored 0%)
#   adding: encrypted_images/4003.png (stored 0%)
#   adding: encrypted_images/4004.png (stored 0%)
#   adding: encrypted_images/4005.png (stored 0%)
#   adding: encrypted_images/4006.png (stored 0%)
#   adding: encrypted_images/4007.png (stored 0%)
#   adding: encrypted_images/4008.png (stored 0%)
#   adding: encrypted_images/4009.png (stored 0%)
#   adding: encrypted_images/4010.png (stored 0%)
#   adding: encrypted_images/4011.png (stored 0%)
#   adding: encrypted_images/4012.png (stored 0%)
#   adding: encrypted_images/4013.png (stored 0%)
#   adding: encrypted_images/4014.png (stored 0%)
#   adding: encrypted_images/4015.png (stored 0%)
#   adding: encrypted_images/4016.png (stored 0%)
#   adding: encrypted_images/4017.png (stored 0%)
#   adding: encrypted_images/4018.png (stored 0%)
#   adding: encrypted_images/4019.png (stored 0%)
#   adding: encrypted_images/4020.png (stored 0%)
#   adding: encrypted_images/4021.png (stored 0%)
#   adding: encrypted_images/4022.png (stored 0%)
#   adding: encrypted_images/4023.png (stored 0%)
#   adding: encrypted_images/4024.png (stored 0%)
#   adding: encrypted_images/4025.png (stored 0%)
#   adding: encrypted_images/4026.png (stored 0%)
#   adding: encrypted_images/4027.png (stored 0%)
#   adding: encrypted_images/4028.png (stored 0%)
#   adding: encrypted_images/4029.png (stored 0%)
#   adding: encrypted_images/4030.png (stored 0%)
#   adding: encrypted_images/4031.png (stored 0%)
#   adding: encrypted_images/4032.png (stored 0%)
#   adding: encrypted_images/4033.png (stored 0%)
#   adding: encrypted_images/4034.png (stored 0%)
#   adding: encrypted_images/4035.png (stored 0%)
#   adding: encrypted_images/4036.png (stored 0%)
#   adding: encrypted_images/4037.png (stored 0%)
#   adding: encrypted_images/4038.png (stored 0%)
#   adding: encrypted_images/4039.png (stored 0%)
#   adding: encrypted_images/4040.png (stored 0%)
#   adding: encrypted_images/4041.png (stored 0%)
#   adding: encrypted_images/4042.png (stored 0%)
#   adding: encrypted_images/4043.png (stored 0%)
#   adding: encrypted_images/4044.png (stored 0%)
#   adding: encrypted_images/4045.png (stored 0%)
#   adding: encrypted_images/4046.png (stored 0%)
#   adding: encrypted_images/4047.png (stored 0%)
#   adding: encrypted_images/4048.png (deflated 3%)
#   adding: encrypted_images/4049.png (stored 0%)
#   adding: encrypted_images/4050.png (stored 0%)
#   adding: encrypted_images/4051.png (stored 0%)
#   adding: encrypted_images/4052.png (stored 0%)
#   adding: encrypted_images/4053.png (stored 0%)
#   adding: encrypted_images/4054.png (stored 0%)
#   adding: encrypted_images/4055.png (stored 0%)
#   adding: encrypted_images/4056.png (stored 0%)
#   adding: encrypted_images/4057.png (stored 0%)
#   adding: encrypted_images/4058.png (stored 0%)
#   adding: encrypted_images/4059.png (stored 0%)
#   adding: encrypted_images/4060.png (stored 0%)
#   adding: encrypted_images/4061.png (stored 0%)
#   adding: encrypted_images/4062.png (stored 0%)
#   adding: encrypted_images/4063.png (stored 0%)
#   adding: encrypted_images/4064.png (stored 0%)
#   adding: encrypted_images/4065.png (stored 0%)
#   adding: encrypted_images/4066.png (stored 0%)
#   adding: encrypted_images/4067.png (stored 0%)
#   adding: encrypted_images/4068.png (stored 0%)
#   adding: encrypted_images/4069.png (stored 0%)
#   adding: encrypted_images/4070.png (stored 0%)
#   adding: encrypted_images/4071.png (stored 0%)
#   adding: encrypted_images/4072.png (stored 0%)
#   adding: encrypted_images/4073.png (stored 0%)
#   adding: encrypted_images/4074.png (stored 0%)
#   adding: encrypted_images/4075.png (stored 0%)
#   adding: encrypted_images/4076.png (stored 0%)
#   adding: encrypted_images/4077.png (stored 0%)
#   adding: encrypted_images/4078.png (stored 0%)
#   adding: encrypted_images/4079.png (stored 0%)
#   adding: encrypted_images/4080.png (stored 0%)
#   adding: encrypted_images/4081.png (stored 0%)
#   adding: encrypted_images/4082.png (stored 0%)
#   adding: encrypted_images/4083.png (stored 0%)
#   adding: encrypted_images/4084.png (stored 0%)
#   adding: encrypted_images/4085.png (stored 0%)
#   adding: encrypted_images/4086.png (stored 0%)
#   adding: encrypted_images/4087.png (stored 0%)
#   adding: encrypted_images/4088.png (stored 0%)
#   adding: encrypted_images/4089.png (stored 0%)
#   adding: encrypted_images/4090.png (stored 0%)
#   adding: encrypted_images/4091.png (stored 0%)
#   adding: encrypted_images/4092.png (stored 0%)
#   adding: encrypted_images/4093.png (stored 0%)
#   adding: encrypted_images/4094.png (stored 0%)
#   adding: encrypted_images/4095.png (stored 0%)
#   adding: encrypted_images/4096.png (stored 0%)
#   adding: encrypted_images/4097.png (stored 0%)
#   adding: encrypted_images/4098.png (stored 0%)
#   adding: encrypted_images/4099.png (stored 0%)
#   adding: encrypted_images/4100.png (stored 0%)
#   adding: encrypted_images/4101.png (stored 0%)
#   adding: encrypted_images/4102.png (stored 0%)
#   adding: encrypted_images/4103.png (stored 0%)
#   adding: encrypted_images/4104.png (stored 0%)
#   adding: encrypted_images/4105.png (stored 0%)
#   adding: encrypted_images/4106.png (stored 0%)
#   adding: encrypted_images/4107.png (stored 0%)
#   adding: encrypted_images/4108.png (stored 0%)
#   adding: encrypted_images/4109.png (stored 0%)
#   adding: encrypted_images/4110.png (stored 0%)
#   adding: encrypted_images/4111.png (stored 0%)
#   adding: encrypted_images/4112.png (stored 0%)
#   adding: encrypted_images/4113.png (stored 0%)
#   adding: encrypted_images/4114.png (stored 0%)
#   adding: encrypted_images/4115.png (stored 0%)
#   adding: encrypted_images/4116.png (stored 0%)
#   adding: encrypted_images/4117.png (deflated 4%)
#   adding: encrypted_images/4118.png (stored 0%)
#   adding: encrypted_images/4119.png (stored 0%)
#   adding: encrypted_images/4120.png (stored 0%)
#   adding: encrypted_images/4121.png (stored 0%)
#   adding: encrypted_images/4122.png (stored 0%)
#   adding: encrypted_images/4123.png (stored 0%)
#   adding: encrypted_images/4124.png (stored 0%)
#   adding: encrypted_images/4125.png (stored 0%)
#   adding: encrypted_images/4126.png (stored 0%)
#   adding: encrypted_images/4127.png (stored 0%)
#   adding: encrypted_images/4128.png (stored 0%)
#   adding: encrypted_images/4129.png (deflated 2%)
#   adding: encrypted_images/4130.png (stored 0%)
#   adding: encrypted_images/4131.png (stored 0%)
#   adding: encrypted_images/4132.png (stored 0%)
#   adding: encrypted_images/4133.png (stored 0%)
#   adding: encrypted_images/4134.png (stored 0%)
#   adding: encrypted_images/4135.png (stored 0%)
#   adding: encrypted_images/4136.png (stored 0%)
#   adding: encrypted_images/4137.png (stored 0%)
#   adding: encrypted_images/4138.png (stored 0%)
#   adding: encrypted_images/4139.png (stored 0%)
#   adding: encrypted_images/4140.png (stored 0%)
#   adding: encrypted_images/4141.png (stored 0%)
#   adding: encrypted_images/4142.png (stored 0%)
#   adding: encrypted_images/4143.png (stored 0%)
#   adding: encrypted_images/4144.png (stored 0%)
#   adding: encrypted_images/4145.png (stored 0%)
#   adding: encrypted_images/4146.png (stored 0%)
#   adding: encrypted_images/4147.png (stored 0%)
#   adding: encrypted_images/4148.png (stored 0%)
#   adding: encrypted_images/4149.png (stored 0%)
#   adding: encrypted_images/4150.png (stored 0%)
#   adding: encrypted_images/4151.png (stored 0%)
#   adding: encrypted_images/4152.png (stored 0%)
#   adding: encrypted_images/4153.png (stored 0%)
#   adding: encrypted_images/4154.png (stored 0%)
#   adding: encrypted_images/4155.png (stored 0%)
#   adding: encrypted_images/4156.png (stored 0%)
#   adding: encrypted_images/4157.png (stored 0%)
#   adding: encrypted_images/4158.png (stored 0%)
#   adding: encrypted_images/4159.png (stored 0%)
#   adding: encrypted_images/4160.png (stored 0%)
#   adding: encrypted_images/4161.png (stored 0%)
#   adding: encrypted_images/4162.png (stored 0%)
#   adding: encrypted_images/4163.png (stored 0%)
#   adding: encrypted_images/4164.png (stored 0%)
#   adding: encrypted_images/4165.png (stored 0%)
#   adding: encrypted_images/4166.png (stored 0%)
#   adding: encrypted_images/4167.png (stored 0%)
#   adding: encrypted_images/4168.png (stored 0%)
#   adding: encrypted_images/4169.png (stored 0%)
#   adding: encrypted_images/4170.png (stored 0%)
#   adding: encrypted_images/4171.png (stored 0%)
#   adding: encrypted_images/4172.png (stored 0%)
#   adding: encrypted_images/4173.png (stored 0%)
#   adding: encrypted_images/4174.png (deflated 3%)
#   adding: encrypted_images/4175.png (stored 0%)
#   adding: encrypted_images/4176.png (stored 0%)
#   adding: encrypted_images/4177.png (stored 0%)
#   adding: encrypted_images/4178.png (stored 0%)
#   adding: encrypted_images/4179.png (stored 0%)
#   adding: encrypted_images/4180.png (stored 0%)
#   adding: encrypted_images/4181.png (stored 0%)
#   adding: encrypted_images/4182.png (stored 0%)
#   adding: encrypted_images/4183.png (stored 0%)
#   adding: encrypted_images/4184.png (stored 0%)
#   adding: encrypted_images/4185.png (stored 0%)
#   adding: encrypted_images/4186.png (stored 0%)
#   adding: encrypted_images/4187.png (stored 0%)
#   adding: encrypted_images/4188.png (stored 0%)
#   adding: encrypted_images/4189.png (stored 0%)
#   adding: encrypted_images/4190.png (stored 0%)
#   adding: encrypted_images/4191.png (stored 0%)
#   adding: encrypted_images/4192.png (stored 0%)
#   adding: encrypted_images/4193.png (stored 0%)
#   adding: encrypted_images/4194.png (stored 0%)
#   adding: encrypted_images/4195.png (stored 0%)
#   adding: encrypted_images/4196.png (stored 0%)
#   adding: encrypted_images/4197.png (stored 0%)
#   adding: encrypted_images/4198.png (stored 0%)
#   adding: encrypted_images/4199.png (stored 0%)
#   adding: encrypted_images/4200.png (stored 0%)
#   adding: encrypted_images/4201.png (stored 0%)
#   adding: encrypted_images/4202.png (stored 0%)
#   adding: encrypted_images/4203.png (stored 0%)
#   adding: encrypted_images/4204.png (stored 0%)
#   adding: encrypted_images/4205.png (stored 0%)
#   adding: encrypted_images/4206.png (stored 0%)
#   adding: encrypted_images/4207.png (stored 0%)
#   adding: encrypted_images/4208.png (stored 0%)
#   adding: encrypted_images/4209.png (stored 0%)
#   adding: encrypted_images/4210.png (stored 0%)
#   adding: encrypted_images/4211.png (stored 0%)
#   adding: encrypted_images/4212.png (stored 0%)
#   adding: encrypted_images/4213.png (stored 0%)
#   adding: encrypted_images/4214.png (stored 0%)
#   adding: encrypted_images/4215.png (stored 0%)
#   adding: encrypted_images/4216.png (stored 0%)
#   adding: encrypted_images/4217.png (stored 0%)
#   adding: encrypted_images/4218.png (stored 0%)
#   adding: encrypted_images/4219.png (stored 0%)
#   adding: encrypted_images/4220.png (stored 0%)
#   adding: encrypted_images/4221.png (stored 0%)
#   adding: encrypted_images/4222.png (stored 0%)
#   adding: encrypted_images/4223.png (stored 0%)
#   adding: encrypted_images/4224.png (stored 0%)
#   adding: encrypted_images/4225.png (stored 0%)
#   adding: encrypted_images/4226.png (stored 0%)
#   adding: encrypted_images/4227.png (stored 0%)
#   adding: encrypted_images/4228.png (stored 0%)
#   adding: encrypted_images/4229.png (stored 0%)
#   adding: encrypted_images/4230.png (stored 0%)
#   adding: encrypted_images/4231.png (stored 0%)
#   adding: encrypted_images/4232.png (stored 0%)
#   adding: encrypted_images/4233.png (stored 0%)
#   adding: encrypted_images/4234.png (stored 0%)
#   adding: encrypted_images/4235.png (stored 0%)
#   adding: encrypted_images/4236.png (stored 0%)
#   adding: encrypted_images/4237.png (stored 0%)
#   adding: encrypted_images/4238.png (stored 0%)
#   adding: encrypted_images/4239.png (stored 0%)
#   adding: encrypted_images/4240.png (stored 0%)
#   adding: encrypted_images/4241.png (stored 0%)
#   adding: encrypted_images/4242.png (stored 0%)
#   adding: encrypted_images/4243.png (stored 0%)
#   adding: encrypted_images/4244.png (stored 0%)
#   adding: encrypted_images/4245.png (stored 0%)
#   adding: encrypted_images/4246.png (stored 0%)
#   adding: encrypted_images/4247.png (stored 0%)
#   adding: encrypted_images/4248.png (stored 0%)
#   adding: encrypted_images/4249.png (stored 0%)
#   adding: encrypted_images/4250.png (stored 0%)
#   adding: encrypted_images/4251.png (stored 0%)
#   adding: encrypted_images/4252.png (stored 0%)
#   adding: encrypted_images/4253.png (stored 0%)
#   adding: encrypted_images/4254.png (stored 0%)
#   adding: encrypted_images/4255.png (stored 0%)
#   adding: encrypted_images/4256.png (stored 0%)
#   adding: encrypted_images/4257.png (stored 0%)
#   adding: encrypted_images/4258.png (stored 0%)
#   adding: encrypted_images/4259.png (stored 0%)
#   adding: encrypted_images/4260.png (stored 0%)
#   adding: encrypted_images/4261.png (stored 0%)
#   adding: encrypted_images/4262.png (stored 0%)
#   adding: encrypted_images/4263.png (stored 0%)
#   adding: encrypted_images/4264.png (stored 0%)
#   adding: encrypted_images/4265.png (stored 0%)
#   adding: encrypted_images/4266.png (stored 0%)
#   adding: encrypted_images/4267.png (stored 0%)
#   adding: encrypted_images/4268.png (stored 0%)
#   adding: encrypted_images/4269.png (stored 0%)
#   adding: encrypted_images/4270.png (stored 0%)
#   adding: encrypted_images/4271.png (stored 0%)
#   adding: encrypted_images/4272.png (stored 0%)
#   adding: encrypted_images/4273.png (stored 0%)
#   adding: encrypted_images/4274.png (stored 0%)
#   adding: encrypted_images/4275.png (stored 0%)
#   adding: encrypted_images/4276.png (stored 0%)
#   adding: encrypted_images/4277.png (stored 0%)
#   adding: encrypted_images/4278.png (stored 0%)
#   adding: encrypted_images/4279.png (stored 0%)
#   adding: encrypted_images/4280.png (stored 0%)
#   adding: encrypted_images/4281.png (stored 0%)
#   adding: encrypted_images/4282.png (stored 0%)
#   adding: encrypted_images/4283.png (stored 0%)
#   adding: encrypted_images/4284.png (stored 0%)
#   adding: encrypted_images/4285.png (stored 0%)
#   adding: encrypted_images/4286.png (stored 0%)
#   adding: encrypted_images/4287.png (stored 0%)
#   adding: encrypted_images/4288.png (stored 0%)
#   adding: encrypted_images/4289.png (stored 0%)
#   adding: encrypted_images/4290.png (stored 0%)
#   adding: encrypted_images/4291.png (stored 0%)
#   adding: encrypted_images/4292.png (stored 0%)
#   adding: encrypted_images/4293.png (stored 0%)
#   adding: encrypted_images/4294.png (stored 0%)
#   adding: encrypted_images/4295.png (stored 0%)
#   adding: encrypted_images/4296.png (stored 0%)
#   adding: encrypted_images/4297.png (stored 0%)
#   adding: encrypted_images/4298.png (stored 0%)
#   adding: encrypted_images/4299.png (stored 0%)
#   adding: encrypted_images/4300.png (stored 0%)
#   adding: encrypted_images/4301.png (stored 0%)
#   adding: encrypted_images/4302.png (stored 0%)
#   adding: encrypted_images/4303.png (stored 0%)
#   adding: encrypted_images/4304.png (stored 0%)
#   adding: encrypted_images/4305.png (stored 0%)
#   adding: encrypted_images/4306.png (stored 0%)
#   adding: encrypted_images/4307.png (stored 0%)
#   adding: encrypted_images/4308.png (stored 0%)
#   adding: encrypted_images/4309.png (stored 0%)
#   adding: encrypted_images/4310.png (stored 0%)
#   adding: encrypted_images/4311.png (stored 0%)
#   adding: encrypted_images/4312.png (stored 0%)
#   adding: encrypted_images/4313.png (stored 0%)
#   adding: encrypted_images/4314.png (stored 0%)
#   adding: encrypted_images/4315.png (stored 0%)
#   adding: encrypted_images/4316.png (stored 0%)
#   adding: encrypted_images/4317.png (stored 0%)
#   adding: encrypted_images/4318.png (stored 0%)
#   adding: encrypted_images/4319.png (stored 0%)
#   adding: encrypted_images/4320.png (stored 0%)
#   adding: encrypted_images/4321.png (stored 0%)
#   adding: encrypted_images/4322.png (stored 0%)
#   adding: encrypted_images/4323.png (stored 0%)
#   adding: encrypted_images/4324.png (stored 0%)
#   adding: encrypted_images/4325.png (stored 0%)
#   adding: encrypted_images/4326.png (stored 0%)
#   adding: encrypted_images/4327.png (stored 0%)
#   adding: encrypted_images/4328.png (stored 0%)
#   adding: encrypted_images/4329.png (stored 0%)
#   adding: encrypted_images/4330.png (stored 0%)
#   adding: encrypted_images/4331.png (stored 0%)
#   adding: encrypted_images/4332.png (stored 0%)
#   adding: encrypted_images/4333.png (stored 0%)
#   adding: encrypted_images/4334.png (stored 0%)
#   adding: encrypted_images/4335.png (stored 0%)
#   adding: encrypted_images/4336.png (stored 0%)
#   adding: encrypted_images/4337.png (stored 0%)
#   adding: encrypted_images/4338.png (stored 0%)
#   adding: encrypted_images/4339.png (stored 0%)
#   adding: encrypted_images/4340.png (stored 0%)
#   adding: encrypted_images/4341.png (stored 0%)
#   adding: encrypted_images/4342.png (stored 0%)
#   adding: encrypted_images/4343.png (stored 0%)
#   adding: encrypted_images/4344.png (stored 0%)
#   adding: encrypted_images/4345.png (stored 0%)
#   adding: encrypted_images/4346.png (stored 0%)
#   adding: encrypted_images/4347.png (stored 0%)
#   adding: encrypted_images/4348.png (stored 0%)
#   adding: encrypted_images/4349.png (stored 0%)
#   adding: encrypted_images/4350.png (stored 0%)
#   adding: encrypted_images/4351.png (stored 0%)
#   adding: encrypted_images/4352.png (stored 0%)
#   adding: encrypted_images/4353.png (deflated 4%)
#   adding: encrypted_images/4354.png (stored 0%)
#   adding: encrypted_images/4355.png (stored 0%)
#   adding: encrypted_images/4356.png (stored 0%)
#   adding: encrypted_images/4357.png (stored 0%)
#   adding: encrypted_images/4358.png (stored 0%)
#   adding: encrypted_images/4359.png (stored 0%)
#   adding: encrypted_images/4360.png (stored 0%)
#   adding: encrypted_images/4361.png (stored 0%)
#   adding: encrypted_images/4362.png (stored 0%)
#   adding: encrypted_images/4363.png (stored 0%)
#   adding: encrypted_images/4364.png (stored 0%)
#   adding: encrypted_images/4365.png (stored 0%)
#   adding: encrypted_images/4366.png (stored 0%)
#   adding: encrypted_images/4367.png (stored 0%)
#   adding: encrypted_images/4368.png (stored 0%)
#   adding: encrypted_images/4369.png (stored 0%)
#   adding: encrypted_images/4370.png (stored 0%)
#   adding: encrypted_images/4371.png (stored 0%)
#   adding: encrypted_images/4372.png (stored 0%)
#   adding: encrypted_images/4373.png (stored 0%)
#   adding: encrypted_images/4374.png (stored 0%)
#   adding: encrypted_images/4375.png (stored 0%)
#   adding: encrypted_images/4376.png (stored 0%)
#   adding: encrypted_images/4377.png (stored 0%)
#   adding: encrypted_images/4378.png (stored 0%)
#   adding: encrypted_images/4379.png (stored 0%)
#   adding: encrypted_images/4380.png (stored 0%)
#   adding: encrypted_images/4381.png (stored 0%)
#   adding: encrypted_images/4382.png (stored 0%)
#   adding: encrypted_images/4383.png (stored 0%)
#   adding: encrypted_images/4384.png (stored 0%)
#   adding: encrypted_images/4385.png (stored 0%)
#   adding: encrypted_images/4386.png (stored 0%)
#   adding: encrypted_images/4387.png (deflated 3%)
#   adding: encrypted_images/4388.png (stored 0%)
#   adding: encrypted_images/4389.png (stored 0%)
#   adding: encrypted_images/4390.png (stored 0%)
#   adding: encrypted_images/4391.png (stored 0%)
#   adding: encrypted_images/4392.png (stored 0%)
#   adding: encrypted_images/4393.png (stored 0%)
#   adding: encrypted_images/4394.png (stored 0%)
#   adding: encrypted_images/4395.png (stored 0%)
#   adding: encrypted_images/4396.png (stored 0%)
#   adding: encrypted_images/4397.png (stored 0%)
#   adding: encrypted_images/4398.png (stored 0%)
#   adding: encrypted_images/4399.png (stored 0%)
#   adding: encrypted_images/4400.png (stored 0%)
#   adding: encrypted_images/4401.png (stored 0%)
#   adding: encrypted_images/4402.png (stored 0%)
#   adding: encrypted_images/4403.png (stored 0%)
#   adding: encrypted_images/4404.png (stored 0%)
#   adding: encrypted_images/4405.png (stored 0%)
#   adding: encrypted_images/4406.png (stored 0%)
#   adding: encrypted_images/4407.png (stored 0%)
#   adding: encrypted_images/4408.png (stored 0%)
#   adding: encrypted_images/4409.png (stored 0%)
#   adding: encrypted_images/4410.png (stored 0%)
#   adding: encrypted_images/4411.png (stored 0%)
#   adding: encrypted_images/4412.png (stored 0%)
#   adding: encrypted_images/4413.png (stored 0%)
#   adding: encrypted_images/4414.png (stored 0%)
#   adding: encrypted_images/4415.png (stored 0%)
#   adding: encrypted_images/4416.png (stored 0%)
#   adding: encrypted_images/4417.png (stored 0%)
#   adding: encrypted_images/4418.png (stored 0%)
#   adding: encrypted_images/4419.png (stored 0%)
#   adding: encrypted_images/4420.png (stored 0%)
#   adding: encrypted_images/4421.png (stored 0%)
#   adding: encrypted_images/4422.png (stored 0%)
#   adding: encrypted_images/4423.png (stored 0%)
#   adding: encrypted_images/4424.png (stored 0%)
#   adding: encrypted_images/4425.png (stored 0%)
#   adding: encrypted_images/4426.png (stored 0%)
#   adding: encrypted_images/4427.png (stored 0%)
#   adding: encrypted_images/4428.png (stored 0%)
#   adding: encrypted_images/4429.png (stored 0%)
#   adding: encrypted_images/4430.png (stored 0%)
#   adding: encrypted_images/4431.png (stored 0%)
#   adding: encrypted_images/4432.png (stored 0%)
#   adding: encrypted_images/4433.png (stored 0%)
#   adding: encrypted_images/4434.png (stored 0%)
#   adding: encrypted_images/4435.png (stored 0%)
#   adding: encrypted_images/4436.png (stored 0%)
#   adding: encrypted_images/4437.png (stored 0%)
#   adding: encrypted_images/4438.png (stored 0%)
#   adding: encrypted_images/4439.png (stored 0%)
#   adding: encrypted_images/4440.png (stored 0%)
#   adding: encrypted_images/4441.png (stored 0%)
#   adding: encrypted_images/4442.png (stored 0%)
#   adding: encrypted_images/4443.png (stored 0%)
#   adding: encrypted_images/4444.png (stored 0%)
#   adding: encrypted_images/4445.png (stored 0%)
#   adding: encrypted_images/4446.png (stored 0%)
#   adding: encrypted_images/4447.png (stored 0%)
#   adding: encrypted_images/4448.png (stored 0%)
#   adding: encrypted_images/4449.png (stored 0%)
#   adding: encrypted_images/4450.png (stored 0%)
#   adding: encrypted_images/4451.png (stored 0%)
#   adding: encrypted_images/4452.png (stored 0%)
#   adding: encrypted_images/4453.png (stored 0%)
#   adding: encrypted_images/4454.png (stored 0%)
#   adding: encrypted_images/4455.png (stored 0%)
#   adding: encrypted_images/4456.png (stored 0%)
#   adding: encrypted_images/4457.png (stored 0%)
#   adding: encrypted_images/4458.png (stored 0%)
#   adding: encrypted_images/4459.png (stored 0%)
#   adding: encrypted_images/4460.png (stored 0%)
#   adding: encrypted_images/4461.png (stored 0%)
#   adding: encrypted_images/4462.png (stored 0%)
#   adding: encrypted_images/4463.png (stored 0%)
#   adding: encrypted_images/4464.png (stored 0%)
#   adding: encrypted_images/4465.png (stored 0%)
#   adding: encrypted_images/4466.png (stored 0%)
#   adding: encrypted_images/4467.png (stored 0%)
#   adding: encrypted_images/4468.png (stored 0%)
#   adding: encrypted_images/4469.png (stored 0%)
#   adding: encrypted_images/4470.png (stored 0%)
#   adding: encrypted_images/4471.png (stored 0%)
#   adding: encrypted_images/4472.png (stored 0%)
#   adding: encrypted_images/4473.png (stored 0%)
#   adding: encrypted_images/4474.png (stored 0%)
#   adding: encrypted_images/4475.png (stored 0%)
#   adding: encrypted_images/4476.png (deflated 3%)
#   adding: encrypted_images/4477.png (stored 0%)
#   adding: encrypted_images/4478.png (stored 0%)
#   adding: encrypted_images/4479.png (stored 0%)
#   adding: encrypted_images/4480.png (stored 0%)
#   adding: encrypted_images/4481.png (stored 0%)
#   adding: encrypted_images/4482.png (stored 0%)
#   adding: encrypted_images/4483.png (stored 0%)
#   adding: encrypted_images/4484.png (stored 0%)
#   adding: encrypted_images/4485.png (stored 0%)
#   adding: encrypted_images/4486.png (stored 0%)
#   adding: encrypted_images/4487.png (stored 0%)
#   adding: encrypted_images/4488.png (stored 0%)
#   adding: encrypted_images/4489.png (stored 0%)
#   adding: encrypted_images/4490.png (stored 0%)
#   adding: encrypted_images/4491.png (stored 0%)
#   adding: encrypted_images/4492.png (stored 0%)
#   adding: encrypted_images/4493.png (stored 0%)
#   adding: encrypted_images/4494.png (stored 0%)
#   adding: encrypted_images/4495.png (stored 0%)
#   adding: encrypted_images/4496.png (stored 0%)
#   adding: encrypted_images/4497.png (stored 0%)
#   adding: encrypted_images/4498.png (stored 0%)
#   adding: encrypted_images/4499.png (stored 0%)
#   adding: encrypted_images/4500.png (stored 0%)
#   adding: encrypted_images/4501.png (stored 0%)
#   adding: encrypted_images/4502.png (stored 0%)
#   adding: encrypted_images/4503.png (stored 0%)
#   adding: encrypted_images/4504.png (stored 0%)
#   adding: encrypted_images/4505.png (stored 0%)
#   adding: encrypted_images/4506.png (stored 0%)
#   adding: encrypted_images/4507.png (stored 0%)
#   adding: encrypted_images/4508.png (stored 0%)
#   adding: encrypted_images/4509.png (stored 0%)
#   adding: encrypted_images/4510.png (stored 0%)
#   adding: encrypted_images/4511.png (stored 0%)
#   adding: encrypted_images/4512.png (stored 0%)
#   adding: encrypted_images/4513.png (stored 0%)
#   adding: encrypted_images/4514.png (stored 0%)
#   adding: encrypted_images/4515.png (stored 0%)
#   adding: encrypted_images/4516.png (stored 0%)
#   adding: encrypted_images/4517.png (stored 0%)
#   adding: encrypted_images/4518.png (stored 0%)
#   adding: encrypted_images/4519.png (stored 0%)
#   adding: encrypted_images/4520.png (stored 0%)
#   adding: encrypted_images/4521.png (stored 0%)
#   adding: encrypted_images/4522.png (stored 0%)
#   adding: encrypted_images/4523.png (stored 0%)
#   adding: encrypted_images/4524.png (stored 0%)
#   adding: encrypted_images/4525.png (stored 0%)
#   adding: encrypted_images/4526.png (stored 0%)
#   adding: encrypted_images/4527.png (stored 0%)
#   adding: encrypted_images/4528.png (stored 0%)
#   adding: encrypted_images/4529.png (stored 0%)
#   adding: encrypted_images/4530.png (stored 0%)
#   adding: encrypted_images/4531.png (stored 0%)
#   adding: encrypted_images/4532.png (stored 0%)
#   adding: encrypted_images/4533.png (stored 0%)
#   adding: encrypted_images/4534.png (stored 0%)
#   adding: encrypted_images/4535.png (stored 0%)
#   adding: encrypted_images/4536.png (stored 0%)
#   adding: encrypted_images/4537.png (stored 0%)
#   adding: encrypted_images/4538.png (stored 0%)
#   adding: encrypted_images/4539.png (stored 0%)
#   adding: encrypted_images/4540.png (stored 0%)
#   adding: encrypted_images/4541.png (stored 0%)
#   adding: encrypted_images/4542.png (stored 0%)
#   adding: encrypted_images/4543.png (stored 0%)
#   adding: encrypted_images/4544.png (stored 0%)
#   adding: encrypted_images/4545.png (stored 0%)
#   adding: encrypted_images/4546.png (stored 0%)
#   adding: encrypted_images/4547.png (stored 0%)
#   adding: encrypted_images/4548.png (stored 0%)
#   adding: encrypted_images/4549.png (stored 0%)
#   adding: encrypted_images/4550.png (stored 0%)
#   adding: encrypted_images/4551.png (stored 0%)
#   adding: encrypted_images/4552.png (stored 0%)
#   adding: encrypted_images/4553.png (stored 0%)
#   adding: encrypted_images/4554.png (stored 0%)
#   adding: encrypted_images/4555.png (stored 0%)
#   adding: encrypted_images/4556.png (stored 0%)
#   adding: encrypted_images/4557.png (stored 0%)
#   adding: encrypted_images/4558.png (stored 0%)
#   adding: encrypted_images/4559.png (stored 0%)
#   adding: encrypted_images/4560.png (stored 0%)
#   adding: encrypted_images/4561.png (stored 0%)
#   adding: encrypted_images/4562.png (stored 0%)
#   adding: encrypted_images/4563.png (stored 0%)
#   adding: encrypted_images/4564.png (stored 0%)
#   adding: encrypted_images/4565.png (stored 0%)
#   adding: encrypted_images/4566.png (stored 0%)
#   adding: encrypted_images/4567.png (stored 0%)
#   adding: encrypted_images/4568.png (stored 0%)
#   adding: encrypted_images/4569.png (stored 0%)
#   adding: encrypted_images/4570.png (stored 0%)
#   adding: encrypted_images/4571.png (stored 0%)
#   adding: encrypted_images/4572.png (stored 0%)
#   adding: encrypted_images/4573.png (stored 0%)
#   adding: encrypted_images/4574.png (stored 0%)
#   adding: encrypted_images/4575.png (stored 0%)
#   adding: encrypted_images/4576.png (stored 0%)
#   adding: encrypted_images/4577.png (stored 0%)
#   adding: encrypted_images/4578.png (stored 0%)
#   adding: encrypted_images/4579.png (stored 0%)
#   adding: encrypted_images/4580.png (stored 0%)
#   adding: encrypted_images/4581.png (stored 0%)
#   adding: encrypted_images/4582.png (stored 0%)
#   adding: encrypted_images/4583.png (stored 0%)
#   adding: encrypted_images/4584.png (stored 0%)
#   adding: encrypted_images/4585.png (stored 0%)
#   adding: encrypted_images/4586.png (stored 0%)
#   adding: encrypted_images/4587.png (stored 0%)
#   adding: encrypted_images/4588.png (stored 0%)
#   adding: encrypted_images/4589.png (stored 0%)
#   adding: encrypted_images/4590.png (stored 0%)
#   adding: encrypted_images/4591.png (stored 0%)
#   adding: encrypted_images/4592.png (stored 0%)
#   adding: encrypted_images/4593.png (stored 0%)
#   adding: encrypted_images/4594.png (stored 0%)
#   adding: encrypted_images/4595.png (stored 0%)
#   adding: encrypted_images/4596.png (stored 0%)
#   adding: encrypted_images/4597.png (stored 0%)
#   adding: encrypted_images/4598.png (stored 0%)
#   adding: encrypted_images/4599.png (stored 0%)
#   adding: encrypted_images/4600.png (stored 0%)
#   adding: encrypted_images/4601.png (stored 0%)
#   adding: encrypted_images/4602.png (stored 0%)
#   adding: encrypted_images/4603.png (stored 0%)
#   adding: encrypted_images/4604.png (stored 0%)
#   adding: encrypted_images/4605.png (stored 0%)
#   adding: encrypted_images/4606.png (stored 0%)
#   adding: encrypted_images/4607.png (stored 0%)
#   adding: encrypted_images/4608.png (stored 0%)
#   adding: encrypted_images/4609.png (stored 0%)
#   adding: encrypted_images/4610.png (stored 0%)
#   adding: encrypted_images/4611.png (stored 0%)
#   adding: encrypted_images/4612.png (stored 0%)
#   adding: encrypted_images/4613.png (stored 0%)
#   adding: encrypted_images/4614.png (stored 0%)
#   adding: encrypted_images/4615.png (stored 0%)
#   adding: encrypted_images/4616.png (stored 0%)
#   adding: encrypted_images/4617.png (stored 0%)
#   adding: encrypted_images/4618.png (stored 0%)
#   adding: encrypted_images/4619.png (stored 0%)
#   adding: encrypted_images/4620.png (stored 0%)
#   adding: encrypted_images/4621.png (stored 0%)
#   adding: encrypted_images/4622.png (stored 0%)
#   adding: encrypted_images/4623.png (stored 0%)
#   adding: encrypted_images/4624.png (stored 0%)
#   adding: encrypted_images/4625.png (stored 0%)
#   adding: encrypted_images/4626.png (stored 0%)
#   adding: encrypted_images/4627.png (stored 0%)
#   adding: encrypted_images/4628.png (stored 0%)
#   adding: encrypted_images/4629.png (stored 0%)
#   adding: encrypted_images/4630.png (stored 0%)
#   adding: encrypted_images/4631.png (stored 0%)
#   adding: encrypted_images/4632.png (stored 0%)
#   adding: encrypted_images/4633.png (stored 0%)
#   adding: encrypted_images/4634.png (stored 0%)
#   adding: encrypted_images/4635.png (stored 0%)
#   adding: encrypted_images/4636.png (stored 0%)
#   adding: encrypted_images/4637.png (stored 0%)
#   adding: encrypted_images/4638.png (stored 0%)
#   adding: encrypted_images/4639.png (stored 0%)
#   adding: encrypted_images/4640.png (stored 0%)
#   adding: encrypted_images/4641.png (stored 0%)
#   adding: encrypted_images/4642.png (stored 0%)
#   adding: encrypted_images/4643.png (stored 0%)
#   adding: encrypted_images/4644.png (stored 0%)
#   adding: encrypted_images/4645.png (stored 0%)
#   adding: encrypted_images/4646.png (stored 0%)
#   adding: encrypted_images/4647.png (stored 0%)
#   adding: encrypted_images/4648.png (stored 0%)
#   adding: encrypted_images/4649.png (stored 0%)
#   adding: encrypted_images/4650.png (stored 0%)
#   adding: encrypted_images/4651.png (stored 0%)
#   adding: encrypted_images/4652.png (stored 0%)
#   adding: encrypted_images/4653.png (stored 0%)
#   adding: encrypted_images/4654.png (stored 0%)
#   adding: encrypted_images/4655.png (stored 0%)
#   adding: encrypted_images/4656.png (stored 0%)
#   adding: encrypted_images/4657.png (stored 0%)
#   adding: encrypted_images/4658.png (stored 0%)
#   adding: encrypted_images/4659.png (stored 0%)
#   adding: encrypted_images/4660.png (stored 0%)
#   adding: encrypted_images/4661.png (stored 0%)
#   adding: encrypted_images/4662.png (stored 0%)
#   adding: encrypted_images/4663.png (stored 0%)
#   adding: encrypted_images/4664.png (stored 0%)
#   adding: encrypted_images/4665.png (stored 0%)
#   adding: encrypted_images/4666.png (stored 0%)
#   adding: encrypted_images/4667.png (stored 0%)
#   adding: encrypted_images/4668.png (stored 0%)
#   adding: encrypted_images/4669.png (stored 0%)
#   adding: encrypted_images/4670.png (stored 0%)
#   adding: encrypted_images/4671.png (stored 0%)
#   adding: encrypted_images/4672.png (stored 0%)
#   adding: encrypted_images/4673.png (stored 0%)
#   adding: encrypted_images/4674.png (stored 0%)
#   adding: encrypted_images/4675.png (stored 0%)
#   adding: encrypted_images/4676.png (stored 0%)
#   adding: encrypted_images/4677.png (stored 0%)
#   adding: encrypted_images/4678.png (stored 0%)
#   adding: encrypted_images/4679.png (stored 0%)
#   adding: encrypted_images/4680.png (stored 0%)
#   adding: encrypted_images/4681.png (stored 0%)
#   adding: encrypted_images/4682.png (stored 0%)
#   adding: encrypted_images/4683.png (stored 0%)
#   adding: encrypted_images/4684.png (stored 0%)
#   adding: encrypted_images/4685.png (stored 0%)
#   adding: encrypted_images/4686.png (stored 0%)
#   adding: encrypted_images/4687.png (stored 0%)
#   adding: encrypted_images/4688.png (stored 0%)
#   adding: encrypted_images/4689.png (deflated 2%)
#   adding: encrypted_images/4690.png (stored 0%)
#   adding: encrypted_images/4691.png (stored 0%)
#   adding: encrypted_images/4692.png (stored 0%)
#   adding: encrypted_images/4693.png (stored 0%)
#   adding: encrypted_images/4694.png (stored 0%)
#   adding: encrypted_images/4695.png (stored 0%)
#   adding: encrypted_images/4696.png (stored 0%)
#   adding: encrypted_images/4697.png (stored 0%)
#   adding: encrypted_images/4698.png (stored 0%)
#   adding: encrypted_images/4699.png (stored 0%)
#   adding: encrypted_images/4700.png (stored 0%)
#   adding: encrypted_images/4701.png (stored 0%)
#   adding: encrypted_images/4702.png (stored 0%)
#   adding: encrypted_images/4703.png (stored 0%)
#   adding: encrypted_images/4704.png (stored 0%)
#   adding: encrypted_images/4705.png (stored 0%)
#   adding: encrypted_images/4706.png (stored 0%)
#   adding: encrypted_images/4707.png (stored 0%)
#   adding: encrypted_images/4708.png (stored 0%)
#   adding: encrypted_images/4709.png (stored 0%)
#   adding: encrypted_images/4710.png (stored 0%)
#   adding: encrypted_images/4711.png (stored 0%)
#   adding: encrypted_images/4712.png (stored 0%)
#   adding: encrypted_images/4713.png (stored 0%)
#   adding: encrypted_images/4714.png (stored 0%)
#   adding: encrypted_images/4715.png (stored 0%)
#   adding: encrypted_images/4716.png (stored 0%)
#   adding: encrypted_images/4717.png (stored 0%)
#   adding: encrypted_images/4718.png (stored 0%)
#   adding: encrypted_images/4719.png (stored 0%)
#   adding: encrypted_images/4720.png (stored 0%)
#   adding: encrypted_images/4721.png (stored 0%)
#   adding: encrypted_images/4722.png (stored 0%)
#   adding: encrypted_images/4723.png (stored 0%)
#   adding: encrypted_images/4724.png (deflated 33%)
#   adding: encrypted_images/4725.png (stored 0%)
#   adding: encrypted_images/4726.png (stored 0%)
#   adding: encrypted_images/4727.png (stored 0%)
#   adding: encrypted_images/4728.png (stored 0%)
#   adding: encrypted_images/4729.png (stored 0%)
#   adding: encrypted_images/4730.png (stored 0%)
#   adding: encrypted_images/4731.png (stored 0%)
#   adding: encrypted_images/4732.png (stored 0%)
#   adding: encrypted_images/4733.png (stored 0%)
#   adding: encrypted_images/4734.png (stored 0%)
#   adding: encrypted_images/4735.png (stored 0%)
#   adding: encrypted_images/4736.png (stored 0%)
#   adding: encrypted_images/4737.png (stored 0%)
#   adding: encrypted_images/4738.png (stored 0%)
#   adding: encrypted_images/4739.png (stored 0%)
#   adding: encrypted_images/4740.png (stored 0%)
#   adding: encrypted_images/4741.png (stored 0%)
#   adding: encrypted_images/4742.png (deflated 3%)
#   adding: encrypted_images/4743.png (stored 0%)
#   adding: encrypted_images/4744.png (stored 0%)
#   adding: encrypted_images/4745.png (stored 0%)
#   adding: encrypted_images/4746.png (stored 0%)
#   adding: encrypted_images/4747.png (stored 0%)
#   adding: encrypted_images/4748.png (stored 0%)
#   adding: encrypted_images/4749.png (stored 0%)
#   adding: encrypted_images/4750.png (stored 0%)
#   adding: encrypted_images/4751.png (stored 0%)
#   adding: encrypted_images/4752.png (stored 0%)
#   adding: encrypted_images/4753.png (stored 0%)
#   adding: encrypted_images/4754.png (stored 0%)
#   adding: encrypted_images/4755.png (stored 0%)
#   adding: encrypted_images/4756.png (stored 0%)
#   adding: encrypted_images/4757.png (stored 0%)
#   adding: encrypted_images/4758.png (stored 0%)
#   adding: encrypted_images/4759.png (deflated 0%)
#   adding: encrypted_images/4760.png (stored 0%)
#   adding: encrypted_images/4761.png (stored 0%)
#   adding: encrypted_images/4762.png (stored 0%)
#   adding: encrypted_images/4763.png (stored 0%)
#   adding: encrypted_images/4764.png (deflated 1%)
#   adding: encrypted_images/4765.png (stored 0%)
#   adding: encrypted_images/4766.png (stored 0%)
#   adding: encrypted_images/4767.png (stored 0%)
#   adding: encrypted_images/4768.png (stored 0%)
#   adding: encrypted_images/4769.png (stored 0%)
#   adding: encrypted_images/4770.png (stored 0%)
#   adding: encrypted_images/4771.png (stored 0%)
#   adding: encrypted_images/4772.png (stored 0%)
#   adding: encrypted_images/4773.png (stored 0%)
#   adding: encrypted_images/4774.png (stored 0%)
#   adding: encrypted_images/4775.png (stored 0%)
#   adding: encrypted_images/4776.png (stored 0%)
#   adding: encrypted_images/4777.png (stored 0%)
#   adding: encrypted_images/4778.png (stored 0%)
#   adding: encrypted_images/4779.png (stored 0%)
#   adding: encrypted_images/4780.png (stored 0%)
#   adding: encrypted_images/4781.png (stored 0%)
#   adding: encrypted_images/4782.png (stored 0%)
#   adding: encrypted_images/4783.png (stored 0%)
#   adding: encrypted_images/4784.png (stored 0%)
#   adding: encrypted_images/4785.png (stored 0%)
#   adding: encrypted_images/4786.png (stored 0%)
#   adding: encrypted_images/4787.png (stored 0%)
#   adding: encrypted_images/4788.png (stored 0%)
#   adding: encrypted_images/4789.png (stored 0%)
#   adding: encrypted_images/4790.png (stored 0%)
#   adding: encrypted_images/4791.png (stored 0%)
#   adding: encrypted_images/4792.png (stored 0%)
#   adding: encrypted_images/4793.png (stored 0%)
#   adding: encrypted_images/4794.png (stored 0%)
#   adding: encrypted_images/4795.png (stored 0%)
#   adding: encrypted_images/4796.png (stored 0%)
#   adding: encrypted_images/4797.png (stored 0%)
#   adding: encrypted_images/4798.png (stored 0%)
#   adding: encrypted_images/4799.png (stored 0%)
#   adding: encrypted_images/4800.png (stored 0%)
#   adding: encrypted_images/4801.png (stored 0%)
#   adding: encrypted_images/4802.png (stored 0%)
#   adding: encrypted_images/4803.png (stored 0%)
#   adding: encrypted_images/4804.png (stored 0%)
#   adding: encrypted_images/4805.png (stored 0%)
#   adding: encrypted_images/4806.png (stored 0%)
#   adding: encrypted_images/4807.png (stored 0%)
#   adding: encrypted_images/4808.png (stored 0%)
#   adding: encrypted_images/4809.png (stored 0%)
#   adding: encrypted_images/4810.png (stored 0%)
#   adding: encrypted_images/4811.png (stored 0%)
#   adding: encrypted_images/4812.png (stored 0%)
#   adding: encrypted_images/4813.png (stored 0%)
#   adding: encrypted_images/4814.png (stored 0%)
#   adding: encrypted_images/4815.png (stored 0%)
#   adding: encrypted_images/4816.png (stored 0%)
#   adding: encrypted_images/4817.png (stored 0%)
#   adding: encrypted_images/4818.png (stored 0%)
#   adding: encrypted_images/4819.png (stored 0%)
#   adding: encrypted_images/4820.png (stored 0%)
#   adding: encrypted_images/4821.png (stored 0%)
#   adding: encrypted_images/4822.png (stored 0%)
#   adding: encrypted_images/4823.png (stored 0%)
#   adding: encrypted_images/4824.png (stored 0%)
#   adding: encrypted_images/4825.png (stored 0%)
#   adding: encrypted_images/4826.png (stored 0%)
#   adding: encrypted_images/4827.png (stored 0%)
#   adding: encrypted_images/4828.png (stored 0%)
#   adding: encrypted_images/4829.png (stored 0%)
#   adding: encrypted_images/4830.png (stored 0%)
#   adding: encrypted_images/4831.png (stored 0%)
#   adding: encrypted_images/4832.png (stored 0%)
#   adding: encrypted_images/4833.png (stored 0%)
#   adding: encrypted_images/4834.png (stored 0%)
#   adding: encrypted_images/4835.png (stored 0%)
#   adding: encrypted_images/4836.png (stored 0%)
#   adding: encrypted_images/4837.png (stored 0%)
#   adding: encrypted_images/4838.png (stored 0%)
#   adding: encrypted_images/4839.png (stored 0%)
#   adding: encrypted_images/4840.png (stored 0%)
#   adding: encrypted_images/4841.png (stored 0%)
#   adding: encrypted_images/4842.png (stored 0%)
#   adding: encrypted_images/4843.png (stored 0%)
#   adding: encrypted_images/4844.png (stored 0%)
#   adding: encrypted_images/4845.png (stored 0%)
#   adding: encrypted_images/4846.png (stored 0%)
#   adding: encrypted_images/4847.png (stored 0%)
#   adding: encrypted_images/4848.png (stored 0%)
#   adding: encrypted_images/4849.png (stored 0%)
#   adding: encrypted_images/4850.png (stored 0%)
#   adding: encrypted_images/4851.png (stored 0%)
#   adding: encrypted_images/4852.png (stored 0%)
#   adding: encrypted_images/4853.png (stored 0%)
#   adding: encrypted_images/4854.png (stored 0%)
#   adding: encrypted_images/4855.png (stored 0%)
#   adding: encrypted_images/4856.png (stored 0%)
#   adding: encrypted_images/4857.png (stored 0%)
#   adding: encrypted_images/4858.png (stored 0%)
#   adding: encrypted_images/4859.png (stored 0%)
#   adding: encrypted_images/4860.png (stored 0%)
#   adding: encrypted_images/4861.png (stored 0%)
#   adding: encrypted_images/4862.png (stored 0%)
#   adding: encrypted_images/4863.png (stored 0%)
#   adding: encrypted_images/4864.png (stored 0%)
#   adding: encrypted_images/4865.png (stored 0%)
#   adding: encrypted_images/4866.png (stored 0%)
#   adding: encrypted_images/4867.png (stored 0%)
#   adding: encrypted_images/4868.png (stored 0%)
#   adding: encrypted_images/4869.png (deflated 3%)
#   adding: encrypted_images/4870.png (stored 0%)
#   adding: encrypted_images/4871.png (stored 0%)
#   adding: encrypted_images/4872.png (stored 0%)
#   adding: encrypted_images/4873.png (stored 0%)
#   adding: encrypted_images/4874.png (stored 0%)
#   adding: encrypted_images/4875.png (stored 0%)
#   adding: encrypted_images/4876.png (stored 0%)
#   adding: encrypted_images/4877.png (stored 0%)
#   adding: encrypted_images/4878.png (stored 0%)
#   adding: encrypted_images/4879.png (stored 0%)
#   adding: encrypted_images/4880.png (stored 0%)
#   adding: encrypted_images/4881.png (stored 0%)
#   adding: encrypted_images/4882.png (stored 0%)
#   adding: encrypted_images/4883.png (stored 0%)
#   adding: encrypted_images/4884.png (stored 0%)
#   adding: encrypted_images/4885.png (stored 0%)
#   adding: encrypted_images/4886.png (stored 0%)
#   adding: encrypted_images/4887.png (stored 0%)
#   adding: encrypted_images/4888.png (stored 0%)
#   adding: encrypted_images/4889.png (stored 0%)
#   adding: encrypted_images/4890.png (stored 0%)
#   adding: encrypted_images/4891.png (stored 0%)
#   adding: encrypted_images/4892.png (stored 0%)
#   adding: encrypted_images/4893.png (stored 0%)
#   adding: encrypted_images/4894.png (stored 0%)
#   adding: encrypted_images/4895.png (stored 0%)
#   adding: encrypted_images/4896.png (stored 0%)
#   adding: encrypted_images/4897.png (stored 0%)
#   adding: encrypted_images/4898.png (stored 0%)
#   adding: encrypted_images/4899.png (stored 0%)
#   adding: encrypted_images/4900.png (stored 0%)
#   adding: encrypted_images/4901.png (stored 0%)
#   adding: encrypted_images/4902.png (stored 0%)
#   adding: encrypted_images/4903.png (stored 0%)
#   adding: encrypted_images/4904.png (stored 0%)
#   adding: encrypted_images/4905.png (stored 0%)
#   adding: encrypted_images/4906.png (stored 0%)
#   adding: encrypted_images/4907.png (stored 0%)
#   adding: encrypted_images/4908.png (stored 0%)
#   adding: encrypted_images/4909.png (stored 0%)
#   adding: encrypted_images/4910.png (stored 0%)
#   adding: encrypted_images/4911.png (stored 0%)
#   adding: encrypted_images/4912.png (stored 0%)
#   adding: encrypted_images/4913.png (stored 0%)
#   adding: encrypted_images/4914.png (stored 0%)
#   adding: encrypted_images/4915.png (stored 0%)
#   adding: encrypted_images/4916.png (deflated 1%)
#   adding: encrypted_images/4917.png (stored 0%)
#   adding: encrypted_images/4918.png (stored 0%)
#   adding: encrypted_images/4919.png (stored 0%)
#   adding: encrypted_images/4920.png (stored 0%)
#   adding: encrypted_images/4921.png (stored 0%)
#   adding: encrypted_images/4922.png (stored 0%)
#   adding: encrypted_images/4923.png (stored 0%)
#   adding: encrypted_images/4924.png (stored 0%)
#   adding: encrypted_images/4925.png (stored 0%)
#   adding: encrypted_images/4926.png (stored 0%)
#   adding: encrypted_images/4927.png (stored 0%)
#   adding: encrypted_images/4928.png (stored 0%)
#   adding: encrypted_images/4929.png (stored 0%)
#   adding: encrypted_images/4930.png (stored 0%)
#   adding: encrypted_images/4931.png (stored 0%)
#   adding: encrypted_images/4932.png (stored 0%)
#   adding: encrypted_images/4933.png (stored 0%)
#   adding: encrypted_images/4934.png (stored 0%)
#   adding: encrypted_images/4935.png (stored 0%)
#   adding: encrypted_images/4936.png (stored 0%)
#   adding: encrypted_images/4937.png (stored 0%)
#   adding: encrypted_images/4938.png (stored 0%)
#   adding: encrypted_images/4939.png (stored 0%)
#   adding: encrypted_images/4940.png (stored 0%)
#   adding: encrypted_images/4941.png (stored 0%)
#   adding: encrypted_images/4942.png (stored 0%)
#   adding: encrypted_images/4943.png (stored 0%)
#   adding: encrypted_images/4944.png (stored 0%)
#   adding: encrypted_images/4945.png (stored 0%)
#   adding: encrypted_images/4946.png (stored 0%)
#   adding: encrypted_images/4947.png (stored 0%)
#   adding: encrypted_images/4948.png (stored 0%)
#   adding: encrypted_images/4949.png (stored 0%)
#   adding: encrypted_images/4950.png (stored 0%)
#   adding: encrypted_images/4951.png (stored 0%)
#   adding: encrypted_images/4952.png (stored 0%)
#   adding: encrypted_images/4953.png (stored 0%)
#   adding: encrypted_images/4954.png (stored 0%)
#   adding: encrypted_images/4955.png (stored 0%)
#   adding: encrypted_images/4956.png (stored 0%)
#   adding: encrypted_images/4957.png (stored 0%)
#   adding: encrypted_images/4958.png (stored 0%)
#   adding: encrypted_images/4959.png (stored 0%)
#   adding: encrypted_images/4960.png (stored 0%)
#   adding: encrypted_images/4961.png (stored 0%)
#   adding: encrypted_images/4962.png (stored 0%)
#   adding: encrypted_images/4963.png (stored 0%)
#   adding: encrypted_images/4964.png (stored 0%)
#   adding: encrypted_images/4965.png (stored 0%)
#   adding: encrypted_images/4966.png (stored 0%)
#   adding: encrypted_images/4967.png (stored 0%)
#   adding: encrypted_images/4968.png (stored 0%)
#   adding: encrypted_images/4969.png (stored 0%)
#   adding: encrypted_images/4970.png (stored 0%)
#   adding: encrypted_images/4971.png (stored 0%)
#   adding: encrypted_images/4972.png (stored 0%)
#   adding: encrypted_images/4973.png (stored 0%)
#   adding: encrypted_images/4974.png (stored 0%)
#   adding: encrypted_images/4975.png (stored 0%)
#   adding: encrypted_images/4976.png (stored 0%)
#   adding: encrypted_images/4977.png (stored 0%)
#   adding: encrypted_images/4978.png (stored 0%)
#   adding: encrypted_images/4979.png (stored 0%)
#   adding: encrypted_images/4980.png (stored 0%)
#   adding: encrypted_images/4981.png (stored 0%)
#   adding: encrypted_images/4982.png (stored 0%)
#   adding: encrypted_images/4983.png (stored 0%)
#   adding: encrypted_images/4984.png (stored 0%)
#   adding: encrypted_images/4985.png (stored 0%)
#   adding: encrypted_images/4986.png (stored 0%)
#   adding: encrypted_images/4987.png (stored 0%)
#   adding: encrypted_images/4988.png (stored 0%)
#   adding: encrypted_images/4989.png (stored 0%)
#   adding: encrypted_images/4990.png (stored 0%)
#   adding: encrypted_images/4991.png (stored 0%)
#   adding: encrypted_images/4992.png (stored 0%)
#   adding: encrypted_images/4993.png (stored 0%)
#   adding: encrypted_images/4994.png (stored 0%)
#   adding: encrypted_images/4995.png (stored 0%)
#   adding: encrypted_images/4996.png (stored 0%)
#   adding: encrypted_images/4997.png (stored 0%)
# ...
#   adding: encrypted_images/660.png (stored 0%)
#   adding: encrypted_images/661.png (stored 0%)
#   adding: encrypted_images/662.png (stored 0%)
#   adding: encrypted_images/663.png (stored 0%)
#   adding: encrypted_images/664.png (stored 0%)
#   adding: encrypted_images/665.png (stored 0%)
#   adding: encrypted_images/666.png (stored 0%)
#   adding: encrypted_images/667.png (stored 0%)
#   adding: encrypted_images/668.png (stored 0%)
#   adding: encrypted_images/669.png (stored 0%)
#   adding: encrypted_images/670.png (stored 0%)
#   adding: encrypted_images/671.png (stored 0%)
#   adding: encrypted_images/672.png (stored 0%)
#   adding: encrypted_images/673.png (stored 0%)
#   adding: encrypted_images/674.png (stored 0%)
#   adding: encrypted_images/675.png (stored 0%)
#   adding: encrypted_images/676.png (stored 0%)
#   adding: encrypted_images/677.png (stored 0%)
#   adding: encrypted_images/678.png (stored 0%)
#   adding: encrypted_images/679.png (stored 0%)
#   adding: encrypted_images/680.png (stored 0%)
#   adding: encrypted_images/681.png (stored 0%)
#   adding: encrypted_images/682.png (stored 0%)
#   adding: encrypted_images/683.png (stored 0%)
#   adding: encrypted_images/684.png (stored 0%)
#   adding: encrypted_images/685.png (stored 0%)
#   adding: encrypted_images/686.png (stored 0%)
#   adding: encrypted_images/687.png (stored 0%)
#   adding: encrypted_images/688.png (stored 0%)
#   adding: encrypted_images/689.png (stored 0%)
#   adding: encrypted_images/690.png (stored 0%)
#   adding: encrypted_images/691.png (stored 0%)
#   adding: encrypted_images/692.png (stored 0%)
#   adding: encrypted_images/693.png (stored 0%)
#   adding: encrypted_images/694.png (stored 0%)
#   adding: encrypted_images/695.png (stored 0%)
#   adding: encrypted_images/696.png (stored 0%)
#   adding: encrypted_images/697.png (stored 0%)
#   adding: encrypted_images/698.png (stored 0%)
#   adding: encrypted_images/699.png (stored 0%)
#   adding: encrypted_images/700.png (stored 0%)
#   adding: encrypted_images/701.png (stored 0%)
#   adding: encrypted_images/702.png (stored 0%)
#   adding: encrypted_images/703.png (stored 0%)
#   adding: encrypted_images/704.png (stored 0%)
#   adding: encrypted_images/705.png (stored 0%)
#   adding: encrypted_images/706.png (stored 0%)
#   adding: encrypted_images/707.png (stored 0%)
#   adding: encrypted_images/708.png (stored 0%)
#   adding: encrypted_images/709.png (stored 0%)
#   adding: encrypted_images/710.png (stored 0%)
#   adding: encrypted_images/711.png (stored 0%)
#   adding: encrypted_images/712.png (stored 0%)
#   adding: encrypted_images/713.png (stored 0%)
#   adding: encrypted_images/714.png (stored 0%)
#   adding: encrypted_images/715.png (stored 0%)
#   adding: encrypted_images/716.png (stored 0%)
#   adding: encrypted_images/717.png (stored 0%)
#   adding: encrypted_images/718.png (stored 0%)
#   adding: encrypted_images/719.png (stored 0%)
#   adding: encrypted_images/720.png (stored 0%)
#   adding: encrypted_images/721.png (stored 0%)
#   adding: encrypted_images/722.png (stored 0%)
#   adding: encrypted_images/723.png (stored 0%)
#   adding: encrypted_images/724.png (stored 0%)
#   adding: encrypted_images/725.png (deflated 3%)
#   adding: encrypted_images/726.png (stored 0%)
#   adding: encrypted_images/727.png (stored 0%)
#   adding: encrypted_images/728.png (stored 0%)
#   adding: encrypted_images/729.png (stored 0%)
#   adding: encrypted_images/730.png (stored 0%)
#   adding: encrypted_images/731.png (deflated 33%)
#   adding: encrypted_images/732.png (stored 0%)
#   adding: encrypted_images/733.png (stored 0%)
#   adding: encrypted_images/734.png (stored 0%)
#   adding: encrypted_images/735.png (stored 0%)
#   adding: encrypted_images/736.png (stored 0%)
#   adding: encrypted_images/737.png (stored 0%)
#   adding: encrypted_images/738.png (stored 0%)
#   adding: encrypted_images/739.png (stored 0%)
#   adding: encrypted_images/740.png (stored 0%)
#   adding: encrypted_images/741.png (stored 0%)
#   adding: encrypted_images/742.png (stored 0%)
#   adding: encrypted_images/743.png (stored 0%)
#   adding: encrypted_images/744.png (stored 0%)
#   adding: encrypted_images/745.png (stored 0%)
#   adding: encrypted_images/746.png (stored 0%)
#   adding: encrypted_images/747.png (stored 0%)
#   adding: encrypted_images/748.png (stored 0%)
#   adding: encrypted_images/749.png (stored 0%)
#   adding: encrypted_images/750.png (stored 0%)
#   adding: encrypted_images/751.png (stored 0%)
#   adding: encrypted_images/752.png (stored 0%)
#   adding: encrypted_images/753.png (stored 0%)
#   adding: encrypted_images/754.png (stored 0%)
#   adding: encrypted_images/755.png (stored 0%)
#   adding: encrypted_images/756.png (stored 0%)
#   adding: encrypted_images/757.png (stored 0%)
#   adding: encrypted_images/758.png (stored 0%)
#   adding: encrypted_images/759.png (stored 0%)
#   adding: encrypted_images/760.png (stored 0%)
#   adding: encrypted_images/761.png (stored 0%)
#   adding: encrypted_images/762.png (stored 0%)
#   adding: encrypted_images/763.png (stored 0%)
#   adding: encrypted_images/764.png (stored 0%)
#   adding: encrypted_images/765.png (stored 0%)
#   adding: encrypted_images/766.png (stored 0%)
#   adding: encrypted_images/767.png (stored 0%)
#   adding: encrypted_images/768.png (stored 0%)
#   adding: encrypted_images/769.png (stored 0%)
#   adding: encrypted_images/770.png (stored 0%)
#   adding: encrypted_images/771.png (stored 0%)
#   adding: encrypted_images/772.png (stored 0%)
#   adding: encrypted_images/773.png (stored 0%)
#   adding: encrypted_images/774.png (stored 0%)
#   adding: encrypted_images/775.png (stored 0%)
#   adding: encrypted_images/776.png (stored 0%)
#   adding: encrypted_images/777.png (stored 0%)
#   adding: encrypted_images/778.png (stored 0%)
#   adding: encrypted_images/779.png (stored 0%)
#   adding: encrypted_images/780.png (stored 0%)
#   adding: encrypted_images/781.png (stored 0%)
#   adding: encrypted_images/782.png (deflated 3%)
#   adding: encrypted_images/783.png (stored 0%)
#   adding: encrypted_images/784.png (stored 0%)
#   adding: encrypted_images/785.png (stored 0%)
#   adding: encrypted_images/786.png (stored 0%)
#   adding: encrypted_images/787.png (stored 0%)
#   adding: encrypted_images/788.png (stored 0%)
#   adding: encrypted_images/789.png (stored 0%)
#   adding: encrypted_images/790.png (stored 0%)
#   adding: encrypted_images/791.png (stored 0%)
#   adding: encrypted_images/792.png (stored 0%)
#   adding: encrypted_images/793.png (stored 0%)
#   adding: encrypted_images/794.png (stored 0%)
#   adding: encrypted_images/795.png (stored 0%)
#   adding: encrypted_images/796.png (stored 0%)
#   adding: encrypted_images/797.png (deflated 1%)
#   adding: encrypted_images/798.png (stored 0%)
#   adding: encrypted_images/799.png (stored 0%)
#   adding: encrypted_images/800.png (stored 0%)
#   adding: encrypted_images/801.png (stored 0%)
#   adding: encrypted_images/802.png (stored 0%)
#   adding: encrypted_images/803.png (deflated 3%)
#   adding: encrypted_images/804.png (stored 0%)
#   adding: encrypted_images/805.png (stored 0%)
#   adding: encrypted_images/806.png (stored 0%)
#   adding: encrypted_images/807.png (stored 0%)
#   adding: encrypted_images/808.png (stored 0%)
#   adding: encrypted_images/809.png (stored 0%)
#   adding: encrypted_images/810.png (stored 0%)
#   adding: encrypted_images/811.png (stored 0%)
#   adding: encrypted_images/812.png (stored 0%)
#   adding: encrypted_images/813.png (stored 0%)
#   adding: encrypted_images/814.png (stored 0%)
#   adding: encrypted_images/815.png (stored 0%)
#   adding: encrypted_images/816.png (deflated 1%)
#   adding: encrypted_images/817.png (stored 0%)
#   adding: encrypted_images/818.png (stored 0%)
#   adding: encrypted_images/819.png (stored 0%)
#   adding: encrypted_images/820.png (stored 0%)
#   adding: encrypted_images/821.png (stored 0%)
#   adding: encrypted_images/822.png (stored 0%)
#   adding: encrypted_images/823.png (stored 0%)
#   adding: encrypted_images/824.png (stored 0%)
#   adding: encrypted_images/825.png (stored 0%)
#   adding: encrypted_images/826.png (stored 0%)
#   adding: encrypted_images/827.png (stored 0%)
#   adding: encrypted_images/828.png (stored 0%)
#   adding: encrypted_images/829.png (stored 0%)
#   adding: encrypted_images/830.png (stored 0%)
#   adding: encrypted_images/831.png (stored 0%)
#   adding: encrypted_images/832.png (stored 0%)
#   adding: encrypted_images/833.png (stored 0%)
#   adding: encrypted_images/834.png (stored 0%)
#   adding: encrypted_images/835.png (stored 0%)
#   adding: encrypted_images/836.png (stored 0%)
#   adding: encrypted_images/837.png (stored 0%)
#   adding: encrypted_images/838.png (stored 0%)
#   adding: encrypted_images/839.png (stored 0%)
#   adding: encrypted_images/840.png (stored 0%)
#   adding: encrypted_images/841.png (stored 0%)
#   adding: encrypted_images/842.png (stored 0%)
#   adding: encrypted_images/843.png (stored 0%)
#   adding: encrypted_images/844.png (stored 0%)
#   adding: encrypted_images/845.png (stored 0%)
#   adding: encrypted_images/846.png (stored 0%)
#   adding: encrypted_images/847.png (stored 0%)
#   adding: encrypted_images/848.png (stored 0%)
#   adding: encrypted_images/849.png (stored 0%)
#   adding: encrypted_images/850.png (stored 0%)
#   adding: encrypted_images/851.png (stored 0%)
#   adding: encrypted_images/852.png (stored 0%)
#   adding: encrypted_images/853.png (stored 0%)
#   adding: encrypted_images/854.png (stored 0%)
#   adding: encrypted_images/855.png (stored 0%)
#   adding: encrypted_images/856.png (stored 0%)
#   adding: encrypted_images/857.png (stored 0%)
#   adding: encrypted_images/858.png (stored 0%)
#   adding: encrypted_images/859.png (stored 0%)
#   adding: encrypted_images/860.png (stored 0%)
#   adding: encrypted_images/861.png (stored 0%)
#   adding: encrypted_images/862.png (stored 0%)
#   adding: encrypted_images/863.png (stored 0%)
#   adding: encrypted_images/864.png (stored 0%)
#   adding: encrypted_images/865.png (stored 0%)
#   adding: encrypted_images/866.png (stored 0%)
#   adding: encrypted_images/867.png (stored 0%)
#   adding: encrypted_images/868.png (stored 0%)
#   adding: encrypted_images/869.png (stored 0%)
#   adding: encrypted_images/870.png (stored 0%)
#   adding: encrypted_images/871.png (stored 0%)
#   adding: encrypted_images/872.png (stored 0%)
#   adding: encrypted_images/873.png (stored 0%)
#   adding: encrypted_images/874.png (stored 0%)
#   adding: encrypted_images/875.png (stored 0%)
#   adding: encrypted_images/876.png (stored 0%)
#   adding: encrypted_images/877.png (stored 0%)
#   adding: encrypted_images/878.png (stored 0%)
#   adding: encrypted_images/879.png (stored 0%)
#   adding: encrypted_images/880.png (stored 0%)
#   adding: encrypted_images/881.png (stored 0%)
#   adding: encrypted_images/882.png (stored 0%)
#   adding: encrypted_images/883.png (stored 0%)
#   adding: encrypted_images/884.png (stored 0%)
#   adding: encrypted_images/885.png (stored 0%)
#   adding: encrypted_images/886.png (stored 0%)
#   adding: encrypted_images/887.png (stored 0%)
#   adding: encrypted_images/888.png (stored 0%)
#   adding: encrypted_images/889.png (stored 0%)
#   adding: encrypted_images/890.png (stored 0%)
#   adding: encrypted_images/891.png (stored 0%)
#   adding: encrypted_images/892.png (stored 0%)
#   adding: encrypted_images/893.png (stored 0%)
#   adding: encrypted_images/894.png (stored 0%)
#   adding: encrypted_images/895.png (stored 0%)
#   adding: encrypted_images/896.png (stored 0%)
#   adding: encrypted_images/897.png (stored 0%)
#   adding: encrypted_images/898.png (deflated 3%)
#   adding: encrypted_images/899.png (stored 0%)
#   adding: encrypted_images/900.png (stored 0%)
#   adding: encrypted_images/901.png (stored 0%)
#   adding: encrypted_images/902.png (stored 0%)
#   adding: encrypted_images/903.png (stored 0%)
#   adding: encrypted_images/904.png (stored 0%)
#   adding: encrypted_images/905.png (stored 0%)
#   adding: encrypted_images/906.png (stored 0%)
#   adding: encrypted_images/907.png (stored 0%)
#   adding: encrypted_images/908.png (stored 0%)
#   adding: encrypted_images/909.png (stored 0%)
#   adding: encrypted_images/910.png (stored 0%)
#   adding: encrypted_images/911.png (stored 0%)
#   adding: encrypted_images/912.png (stored 0%)
#   adding: encrypted_images/913.png (stored 0%)
#   adding: encrypted_images/914.png (stored 0%)
#   adding: encrypted_images/915.png (stored 0%)
#   adding: encrypted_images/916.png (stored 0%)
#   adding: encrypted_images/917.png (stored 0%)
#   adding: encrypted_images/918.png (stored 0%)
#   adding: encrypted_images/919.png (stored 0%)
#   adding: encrypted_images/920.png (stored 0%)
#   adding: encrypted_images/921.png (stored 0%)
#   adding: encrypted_images/922.png (stored 0%)
#   adding: encrypted_images/923.png (stored 0%)
#   adding: encrypted_images/924.png (stored 0%)
#   adding: encrypted_images/925.png (stored 0%)
#   adding: encrypted_images/926.png (stored 0%)
#   adding: encrypted_images/927.png (stored 0%)
#   adding: encrypted_images/928.png (stored 0%)
#   adding: encrypted_images/929.png (stored 0%)
#   adding: encrypted_images/930.png (stored 0%)
#   adding: encrypted_images/931.png (stored 0%)
#   adding: encrypted_images/932.png (stored 0%)
#   adding: encrypted_images/933.png (stored 0%)
#   adding: encrypted_images/934.png (stored 0%)
#   adding: encrypted_images/935.png (stored 0%)
#   adding: encrypted_images/936.png (stored 0%)
#   adding: encrypted_images/937.png (stored 0%)
#   adding: encrypted_images/938.png (stored 0%)
#   adding: encrypted_images/939.png (stored 0%)
#   adding: encrypted_images/940.png (stored 0%)
#   adding: encrypted_images/941.png (stored 0%)
#   adding: encrypted_images/942.png (stored 0%)
#   adding: encrypted_images/943.png (stored 0%)
#   adding: encrypted_images/944.png (stored 0%)
#   adding: encrypted_images/945.png (stored 0%)
#   adding: encrypted_images/946.png (stored 0%)
#   adding: encrypted_images/947.png (stored 0%)
#   adding: encrypted_images/948.png (stored 0%)
#   adding: encrypted_images/949.png (stored 0%)
#   adding: encrypted_images/950.png (stored 0%)
#   adding: encrypted_images/951.png (stored 0%)
#   adding: encrypted_images/952.png (stored 0%)
#   adding: encrypted_images/953.png (stored 0%)
#   adding: encrypted_images/954.png (stored 0%)
#   adding: encrypted_images/955.png (stored 0%)
#   adding: encrypted_images/956.png (stored 0%)
#   adding: encrypted_images/957.png (stored 0%)
#   adding: encrypted_images/958.png (stored 0%)
#   adding: encrypted_images/959.png (stored 0%)
#   adding: encrypted_images/960.png (stored 0%)
#   adding: encrypted_images/961.png (stored 0%)
#   adding: encrypted_images/962.png (stored 0%)
#   adding: encrypted_images/963.png (stored 0%)
#   adding: encrypted_images/964.png (stored 0%)
#   adding: encrypted_images/965.png (stored 0%)
#   adding: encrypted_images/966.png (stored 0%)
#   adding: encrypted_images/967.png (stored 0%)
#   adding: encrypted_images/968.png (stored 0%)
#   adding: encrypted_images/969.png (deflated 4%)
#   adding: encrypted_images/970.png (stored 0%)
#   adding: encrypted_images/971.png (stored 0%)
#   adding: encrypted_images/972.png (stored 0%)
#   adding: encrypted_images/973.png (stored 0%)
#   adding: encrypted_images/974.png (stored 0%)
#   adding: encrypted_images/975.png (stored 0%)
#   adding: encrypted_images/976.png (stored 0%)
#   adding: encrypted_images/977.png (stored 0%)
#   adding: encrypted_images/978.png (stored 0%)
#   adding: encrypted_images/979.png (stored 0%)
#   adding: encrypted_images/980.png (stored 0%)
#   adding: encrypted_images/981.png (stored 0%)
#   adding: encrypted_images/982.png (stored 0%)
#   adding: encrypted_images/983.png (stored 0%)
#   adding: encrypted_images/984.png (stored 0%)
#   adding: encrypted_images/985.png (stored 0%)
#   adding: encrypted_images/986.png (stored 0%)
#   adding: encrypted_images/987.png (stored 0%)
#   adding: encrypted_images/988.png (stored 0%)
#   adding: encrypted_images/989.png (stored 0%)
#   adding: encrypted_images/990.png (stored 0%)
#   adding: encrypted_images/991.png (stored 0%)
#   adding: encrypted_images/992.png (stored 0%)
#   adding: encrypted_images/993.png (stored 0%)
#   adding: encrypted_images/994.png (stored 0%)
#   adding: encrypted_images/995.png (stored 0%)
#   adding: encrypted_images/996.png (stored 0%)
#   adding: encrypted_images/997.png (stored 0%)
#   adding: encrypted_images/998.png (stored 0%)
#   adding: encrypted_images/999.png (stored 0%)

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to2_cipher.zip"
extract_path = "/content/present_buckets_raw/class_3"
os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    for member in zip_ref.namelist():
        if member.endswith(".png"):
            filename = os.path.basename(member)
            if not filename:
                continue
            source = zip_ref.open(member)
            target = open(os.path.join(extract_path, filename), "wb")
            with source, target:
                shutil.copyfileobj(source, target)

print(" Flattened extraction of class_3 completed.")
# Out:
#  Flattened extraction of class_3 completed.

# %%
images = os.listdir("/content/present_buckets_raw/class_3")
print(f"class_3 now has {len(images)} images")
# Out:
# class_3 now has 50001 images

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Paths
input_root = "/content/present_buckets_raw"
output_root = "/content/present_buckets_split"
train_dir = os.path.join(output_root, "train")
val_dir = os.path.join(output_root, "val")

# Prepare output dirs
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

val_split = 0.2
max_images = 50000

for class_name in sorted(os.listdir(input_root)):
    class_path = os.path.join(input_root, class_name)
    if not os.path.isdir(class_path):
        continue

    # Get only .png or .jpg images, limit to 50k
    images = sorted([img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))])[:max_images]

    if len(images) == 0:
        print(f"Skipping {class_name} — no images found.")
        continue

    train_imgs, val_imgs = train_test_split(images, test_size=val_split, random_state=42)

    # Create class folders for train/val
    train_class_dir = os.path.join(train_dir, class_name)
    val_class_dir = os.path.join(val_dir, class_name)
    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(val_class_dir, exist_ok=True)

    # Copy train images
    for img in train_imgs:
        shutil.copy(os.path.join(class_path, img), os.path.join(train_class_dir, img))

    # Copy val images
    for img in val_imgs:
        shutil.copy(os.path.join(class_path, img), os.path.join(val_class_dir, img))

    print(f" {class_name}: {len(train_imgs)} train, {len(val_imgs)} val images")

print(" All classes split into train/val successfully.")
# Out:
#  class_0: 40000 train, 10000 val images
#  class_1: 40000 train, 10000 val images
#  class_2: 40000 train, 10000 val images
#  class_3: 40000 train, 10000 val images
#  All classes split into train/val successfully.

# %%
# alexnet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

alexnet_model = Sequential([
    Conv2D(96, (3, 3), activation='relu', input_shape=(32, 32, 3), padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2), strides=2),

    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2), strides=2),

    Conv2D(384, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(384, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2), strides=2),

    Flatten(),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(4096, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')  #  4 classes
])

alexnet_model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_dir = "/content/present_buckets_split/train"
val_dir = "/content/present_buckets_split/val"
# Rescale pixels to [0,1]
datagen = ImageDataGenerator(rescale=1./255)
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(32, 32),
    batch_size=128,
    class_mode='categorical'
)
val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(32, 32),
    batch_size=128,
    class_mode='categorical'
)
# Out:
# Found 160000 images belonging to 4 classes.
# Found 40000 images belonging to 4 classes.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = alexnet_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 95s 64ms/step - accuracy: 0.8482 - loss: 0.8306 - val_accuracy: 0.8149 - val_loss: 0.5709
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9856 - loss: 0.0455 - val_accuracy: 0.6108 - val_loss: 1.8577
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9901 - loss: 0.0322 - val_accuracy: 0.9129 - val_loss: 0.3406
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.9910 - loss: 0.0288 - val_accuracy: 0.9781 - val_loss: 0.0629
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9923 - loss: 0.0272 - val_accuracy: 0.8575 - val_loss: 0.8944
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 60ms/step - accuracy: 0.9925 - loss: 0.0284 - val_accuracy: 0.9467 - val_loss: 0.1843
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9941 - loss: 0.0209 - val_accuracy: 0.9887 - val_loss: 0.0418
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9955 - loss: 0.0163 - val_accuracy: 0.6605 - val_loss: 4.6173
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9948 - loss: 0.0195 - val_accuracy: 0.9789 - val_loss: 0.1243
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 61ms/step - accuracy: 0.9959 - loss: 0.0145 - val_accuracy: 0.9165 - val_loss: 0.9684
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9955 - loss: 0.0166 - val_accuracy: 0.9731 - val_loss: 0.1302
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9961 - loss: 0.0163 - val_accuracy: 0.8803 - val_loss: 0.6488

# %%
alexnet_model.fit(
    train_generator,
    validation_data=val_generator,
    initial_epoch=12,   # resume from where you stopped
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9913 - loss: 0.0362 - val_accuracy: 0.9816 - val_loss: 0.0768
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.9945 - loss: 0.0229 - val_accuracy: 0.9855 - val_loss: 0.1084
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9951 - loss: 0.0210 - val_accuracy: 0.9436 - val_loss: 0.2804
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 60ms/step - accuracy: 0.9965 - loss: 0.0125 - val_accuracy: 0.9779 - val_loss: 0.1101
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9971 - loss: 0.0102 - val_accuracy: 0.9513 - val_loss: 0.3418
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 81s 60ms/step - accuracy: 0.9962 - loss: 0.0156 - val_accuracy: 0.9172 - val_loss: 0.5260

# %%
alexnet_model.save("alexnet_present_model.keras")

# %%
val_generator_no_shuffle = datagen.flow_from_directory(
    val_dir,
    target_size=(32, 32),
    batch_size=128,
    class_mode='categorical',
    shuffle=False
)

alexnet_model.evaluate(val_generator_no_shuffle)
# Out:
# Found 40000 images belonging to 4 classes.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.9810 - loss: 0.0829
# [0.0768219456076622, 0.9815999865531921]

# %%
from tensorflow.keras.layers import Input, Conv2D, DepthwiseConv2D, BatchNormalization, ReLU, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
def mobilenet_block(x, filters, strides):
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(filters, kernel_size=1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x
def build_mobilenet(input_shape=(32, 32, 3), num_classes=4):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, kernel_size=3, strides=1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = mobilenet_block(x, filters=64, strides=1)
    x = mobilenet_block(x, filters=128, strides=2)
    x = mobilenet_block(x, filters=128, strides=1)
    x = mobilenet_block(x, filters=256, strides=2)
    x = mobilenet_block(x, filters=256, strides=1)
    x = mobilenet_block(x, filters=512, strides=2)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    return model

# %%
mobilenet_model = build_mobilenet()
mobilenet_model.compile(optimizer='adam',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

# %%
history = mobilenet_model.fit(
    train_generator,
    validation_data=val_generator_no_shuffle,
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.8951 - loss: 0.2490 - val_accuracy: 0.9568 - val_loss: 0.1282
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - accuracy: 0.9859 - loss: 0.0377 - val_accuracy: 0.9821 - val_loss: 0.0537
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.9914 - loss: 0.0242 - val_accuracy: 0.9904 - val_loss: 0.0288
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 0.9894 - val_loss: 0.0321
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - accuracy: 0.9955 - loss: 0.0128 - val_accuracy: 0.9858 - val_loss: 0.0432
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - accuracy: 0.9960 - loss: 0.0109 - val_accuracy: 0.9923 - val_loss: 0.0228
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.9970 - loss: 0.0088 - val_accuracy: 0.9823 - val_loss: 0.0626
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9940 - val_loss: 0.0182
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 42ms/step - accuracy: 0.9977 - loss: 0.0063 - val_accuracy: 0.9939 - val_loss: 0.0205
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - accuracy: 0.9976 - loss: 0.0070 - val_accuracy: 0.9845 - val_loss: 0.0543
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.9982 - loss: 0.0049 - val_accuracy: 0.8771 - val_loss: 0.5811
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.9980 - loss: 0.0055 - val_accuracy: 0.9970 - val_loss: 0.0085
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.9960 - val_loss: 0.0115
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 51s 41ms/step - accuracy: 0.9988 - loss: 0.0031 - val_accuracy: 0.9945 - val_loss: 0.0184
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - accuracy: 0.9987 - loss: 0.0037 - val_accuracy: 0.9851 - val_loss: 0.0514
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9790 - val_loss: 0.0841
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 53s 43ms/step - accuracy: 0.9989 - loss: 0.0030 - val_accuracy: 0.9862 - val_loss: 0.0520

# %%
mobilenet_model.save('/content/mobilenet_present_cipher.keras')

# %%
alexnet_model.save('/content/drive/MyDrive/Present_cipher_project/alexnet_present_cipher.h5')

# Save training history
import pickle

with open('/content/drive/MyDrive/Present_cipher_project/alexnet_history.pkl', 'wb') as f:
    pickle.dump(history_alexnet.history, f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-44-1352556935.py in <cell line: 0>()
#       5
#       6 with open('/content/drive/MyDrive/Present_cipher_project/alexnet_history.pkl', 'wb') as f:
# ----> 7     pickle.dump(history_alexnet.history, f)
#
# NameError: name 'history_alexnet' is not defined

# %%
mobilenet_model.save('/content/drive/MyDrive/Present_cipher_project/mobilenet_present_cipher.keras')
import pickle
with open('/content/drive/MyDrive/Present_cipher_project/mobilenet_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
alexnet_model.save('/content/drive/MyDrive/Present_cipher_project/alexnet_present_cipher.keras')

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Retrain AlexNet and save history properly
history_alexnet = alexnet_model.fit(
    train_generator,
    validation_data=val_generator_no_shuffle,  # no shuffle to match label order
    batch_size=128,
    epochs=50,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.9916 - loss: 0.0351 - val_accuracy: 0.9233 - val_loss: 0.2965
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9963 - loss: 0.0142 - val_accuracy: 0.6609 - val_loss: 7.7018
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9961 - loss: 0.0146 - val_accuracy: 0.7991 - val_loss: 2.7756
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9961 - loss: 0.0157 - val_accuracy: 0.7720 - val_loss: 1.1092
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.9972 - loss: 0.0118 - val_accuracy: 0.8741 - val_loss: 0.5122
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9970 - loss: 0.0111 - val_accuracy: 0.9879 - val_loss: 0.0718
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.9975 - loss: 0.0101 - val_accuracy: 0.9041 - val_loss: 0.4950
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9967 - loss: 0.0138 - val_accuracy: 0.5742 - val_loss: 12.5783
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9970 - loss: 0.0127 - val_accuracy: 0.9570 - val_loss: 0.3010
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.9213 - val_loss: 0.4671
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9980 - loss: 0.0077 - val_accuracy: 0.9670 - val_loss: 0.2347
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9968 - loss: 0.0180 - val_accuracy: 0.9867 - val_loss: 0.0508
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9979 - loss: 0.0089 - val_accuracy: 0.6353 - val_loss: 16.8608
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.9973 - loss: 0.0125 - val_accuracy: 0.9724 - val_loss: 0.1617
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9980 - loss: 0.0110 - val_accuracy: 0.9847 - val_loss: 0.0923
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9982 - loss: 0.0071 - val_accuracy: 0.9102 - val_loss: 0.8552
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9981 - loss: 0.0086 - val_accuracy: 0.8409 - val_loss: 3.2830
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 62ms/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9323 - val_loss: 0.7957
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 62ms/step - accuracy: 0.9982 - loss: 0.0077 - val_accuracy: 0.9771 - val_loss: 0.1633
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 62ms/step - accuracy: 0.9987 - loss: 0.0057 - val_accuracy: 0.9898 - val_loss: 0.0558
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9986 - loss: 0.0051 - val_accuracy: 0.9933 - val_loss: 0.0311
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9982 - loss: 0.0090 - val_accuracy: 0.9841 - val_loss: 0.0902
# Epoch 23/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9983 - loss: 0.0094 - val_accuracy: 0.9886 - val_loss: 0.0772
# Epoch 24/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 62ms/step - accuracy: 0.9987 - loss: 0.0064 - val_accuracy: 0.9839 - val_loss: 0.0797
# Epoch 25/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.5786 - val_loss: 5.2417
# Epoch 26/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9983 - loss: 0.0081 - val_accuracy: 0.9533 - val_loss: 0.2469
# Epoch 27/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 76s 61ms/step - accuracy: 0.9988 - loss: 0.0050 - val_accuracy: 0.9704 - val_loss: 0.2443
# Epoch 28/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.9771 - val_loss: 0.1508
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.9987 - loss: 0.0055 - val_accuracy: 0.9878 - val_loss: 0.0685
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 77s 61ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.9851 - val_loss: 0.0886
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 75s 60ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9707 - val_loss: 0.2014

# %%
import pickle
with open('/content/drive/MyDrive/Present_cipher_project/alexnet_history.pkl', 'wb') as f:
    pickle.dump(history_alexnet.history, f)

# %%
import matplotlib.pyplot as plt

# Step 1: Extract .history if needed
# If alexnet_hist is a History object (not a dict), extract its .history dictionary
if hasattr(alexnet_hist, 'history'):
    alexnet_hist = alexnet_hist.history

# Step 2: Get MobileNet's history
mobilenet_hist = history.history  # assuming `history` is from MobileNet model.fit()

# Step 3: Plot Accuracy and Loss
plt.figure(figsize=(14, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(alexnet_hist['accuracy'], label='AlexNet Train', linestyle='--')
plt.plot(alexnet_hist['val_accuracy'], label='AlexNet Val', linestyle='-')
plt.plot(mobilenet_hist['accuracy'], label='MobileNet Train', linestyle='--')
plt.plot(mobilenet_hist['val_accuracy'], label='MobileNet Val', linestyle='-')
plt.title('Model Accuracy Comparison')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(alexnet_hist['loss'], label='AlexNet Train', linestyle='--')
plt.plot(alexnet_hist['val_loss'], label='AlexNet Val', linestyle='-')
plt.plot(mobilenet_hist['loss'], label='MobileNet Train', linestyle='--')
plt.plot(mobilenet_hist['val_loss'], label='MobileNet Val', linestyle='-')
plt.title('Model Loss Comparison')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.models import load_model

alexnet_model = load_model('/content/drive/MyDrive/Present_cipher_project/alexnet_present_cipher.keras')
mobilenet_model = load_model('/content/drive/MyDrive/Present_cipher_project/mobilenet_present_cipher.keras')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 28 variables whereas the saved optimizer has 54 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# !zip -r "/content/drive/MyDrive/Present_cipher_project/present_buckets_split.zip" "/content/present_buckets_split"
# Out:
# 	zip warning: name not matched: /content/present_buckets_split
#
# zip error: Nothing to do! (try: zip -r /content/drive/MyDrive/Present_cipher_project/present_buckets_split.zip . -i /content/present_buckets_split)

# %%
import os, zipfile

# Class names
zips = {
    "present_original.zip": "class_0",
    "present_3to1_cipher.zip": "class_1",
    "present_3to2_cipher.zip": "class_2",
    "present_3to5_cipher.zip": "class_3"
}

for zip_name, class_dir in zips.items():
    zip_path = f"/content/drive/MyDrive/Present_cipher_project/{zip_name}"
    extract_path = f"/content/present_buckets/{class_dir}"
    os.makedirs(extract_path, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print("✅ All classes extracted.")
# Out:
# ✅ All classes extracted.

# %%
input_root = "/content/present_buckets"

for class_name in sorted(os.listdir(input_root)):
    class_path = os.path.join(input_root, class_name)
    images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
    print(f"{class_name}: {len(images)} images")
# Out:
# class_0: 50000 images
# class_1: 0 images
# class_2: 0 images
# class_3: 50000 images

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"
extract_to = "/content/present_buckets/class_1"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to5_cipher.zip"
extract_to = "/content/present_buckets/class_2"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
for class_name in sorted(os.listdir("/content/present_buckets")):
    class_path = os.path.join("/content/present_buckets", class_name)
    images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
    print(f"{class_name}: {len(images)} images")
# Out:
# class_0: 50000 images
# class_1: 0 images
# class_2: 50000 images
# class_3: 50000 images

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"
extract_to = "/content/present_buckets/class_1"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
for class_name in sorted(os.listdir("/content/present_buckets")):
    class_path = os.path.join("/content/present_buckets", class_name)
    images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
    print(f"{class_name}: {len(images)} images")
# Out:
# class_0: 50000 images
# class_1: 0 images
# class_2: 50000 images
# class_3: 50000 images

# %%
import shutil

shutil.rmtree("/content/present_buckets/class_1", ignore_errors=True)

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/Present_cipher_project/present_3to1_cipher.zip"
extract_to = "/content/present_buckets/class_1"

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
import os
import shutil

src_folder = "/content/present_buckets/class_1/encrypted_images"
dest_folder = "/content/present_buckets/class_1"

for filename in os.listdir(src_folder):
    if filename.endswith((".png", ".jpg")):
        shutil.move(os.path.join(src_folder, filename), os.path.join(dest_folder, filename))

# Now remove the empty subfolder
shutil.rmtree(src_folder)

# %%
for class_name in sorted(os.listdir("/content/present_buckets")):
    class_path = os.path.join("/content/present_buckets", class_name)
    images = [img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))]
    print(f"{class_name}: {len(images)} images")
# Out:
# class_0: 50000 images
# class_1: 50000 images
# class_2: 50000 images
# class_3: 50000 images

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

input_root = "/content/present_buckets"
output_root = "/content/present_buckets_split"
train_dir = os.path.join(output_root, "train")
val_dir = os.path.join(output_root, "val")
val_split = 0.2

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

for class_name in sorted(os.listdir(input_root)):
    class_path = os.path.join(input_root, class_name)
    images = sorted([img for img in os.listdir(class_path) if img.endswith((".png", ".jpg"))])

    train_imgs, val_imgs = train_test_split(images, test_size=val_split, random_state=42)

    train_class_dir = os.path.join(train_dir, class_name)
    val_class_dir = os.path.join(val_dir, class_name)
    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(val_class_dir, exist_ok=True)

    for img in train_imgs:
        shutil.copy(os.path.join(class_path, img), os.path.join(train_class_dir, img))
    for img in val_imgs:
        shutil.copy(os.path.join(class_path, img), os.path.join(val_class_dir, img))

    print(f"{class_name}: {len(train_imgs)} train, {len(val_imgs)} val")
# Out:
# class_0: 40000 train, 10000 val
# class_1: 40000 train, 10000 val
# class_2: 40000 train, 10000 val
# class_3: 40000 train, 10000 val

# %%
# !zip -r /content/drive/MyDrive/Present_cipher_project/present_buckets_split.zip /content/present_buckets_split
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/present_buckets_split/val/class_2/train_encrypted_3673.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_14666.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_14306.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49690.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29403.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_5618.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_4444.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39908.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17753.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_45343.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35303.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39399.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_2555.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49389.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_414.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38425.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33680.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6360.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17628.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18115.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_22673.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23437.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_31313.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_36872.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_3832.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46021.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_603.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23733.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25164.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23459.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48869.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_3851.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_34818.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8012.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33610.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6178.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6292.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48075.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_45076.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48453.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_15513.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37859.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6652.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_41367.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37933.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33545.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21226.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40483.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_13040.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_5097.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_15512.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_19253.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21173.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38366.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47778.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48491.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_2864.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40975.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16639.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_28795.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_24039.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47851.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8487.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26609.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39087.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_11777.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21493.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39019.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39441.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_42569.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_34510.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23009.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21385.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_36753.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47581.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_320.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33884.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20167.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43596.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30127.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18845.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_9624.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20802.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10408.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25822.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21509.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_45150.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40407.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_24811.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20414.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38463.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43258.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_13975.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_9676.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27538.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40260.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39824.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1588.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23825.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_36265.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23914.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_32366.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_14828.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_41409.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_13820.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_7533.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_767.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37797.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27710.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_44431.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_32731.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16758.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8574.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8253.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21517.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_5778.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46697.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_12242.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10601.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37786.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47438.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21951.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21579.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49078.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_42469.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47507.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27470.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35809.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_31746.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39919.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38090.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39151.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_31518.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10133.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33185.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_5897.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29368.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_22852.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_19814.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33114.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39506.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_41794.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_32234.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38619.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_11530.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47244.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8056.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6733.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40623.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29087.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46534.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_45671.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_41955.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_7362.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_45448.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27425.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48646.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46470.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_23719.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6072.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10940.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_36950.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46523.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48324.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_2165.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29103.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29739.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46590.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27977.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_33843.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_979.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20616.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16079.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16713.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29509.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48848.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37601.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_5549.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6457.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6112.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35365.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21698.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_44622.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_4659.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26826.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48628.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37090.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_14790.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47891.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43915.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_28492.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_14805.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49554.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_15089.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49561.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30413.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25180.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_31969.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_44747.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_42637.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_12688.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21400.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18262.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49805.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_3456.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30831.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30640.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10356.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10945.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_2161.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40866.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_31840.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10486.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25721.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21122.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_13049.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18246.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38317.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18504.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10605.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_9008.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_14559.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38516.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30404.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_4818.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46875.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_42952.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_9637.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18888.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_34107.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_11637.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21513.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37808.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6681.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8744.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_11059.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17411.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47579.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38662.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20344.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49123.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26376.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46462.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16547.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20132.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35700.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1933.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43042.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_44327.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35449.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6866.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6472.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46955.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_3685.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8275.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_46033.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35596.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_49628.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_12019.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17883.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17235.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_40874.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18582.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43149.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_
png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25674.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27744.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_44520.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_13240.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30482.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_10282.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_13340.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37296.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25798.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_30218.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_12842.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37052.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26352.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21456.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8972.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_21345.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48555.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_8906.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43477.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20452.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_539.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1740.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16765.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1925.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_45243.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48661.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_273.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_34307.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1609.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20540.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1577.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47510.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26347.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38316.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_15555.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25357.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_5775.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26302.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16907.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_9154.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17367.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29869.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_18667.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_6776.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_17619.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_43764.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_27804.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37826.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_1966.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48062.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_29682.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_37184.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_39465.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_9580.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_20067.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_26020.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48441.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_16950.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_4756.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_12916.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_15096.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_3901.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_35812.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_48618.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_38459.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_47990.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25894.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_36312.png (stored 0%)
#   adding: content/present_buckets_split/val/class_2/train_encrypted_25379.png (stored 0%)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

val_dir = "/content/present_buckets_split/val"

datagen = ImageDataGenerator(rescale=1./255)
val_generator_no_shuffle = datagen.flow_from_directory(
    val_dir,
    target_size=(32, 32),
    batch_size=128,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 40000 images belonging to 4 classes.

# %%
import numpy as np

# Load all validation data from the generator
X_test, y_test = [], []

for i in range(len(val_generator_no_shuffle)):
    x_batch, y_batch = val_generator_no_shuffle[i]
    X_test.append(x_batch)
    y_test.append(y_batch)

X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (40000, 32, 32, 3)
# y_test shape: (40000, 4)

# %%
X_test, y_test = next(val_generator_no_shuffle)
for _ in range(4):  # Get more batches to concatenate
    x, y = next(val_generator_no_shuffle)
    X_test = np.concatenate((X_test, x), axis=0)
    y_test = np.concatenate((y_test, y), axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# Class labels
class_names = ['PRESENT', '3→2 S-box', '3→5 S-box', '3→1 S-box']

# Get predictions from both models
y_pred_alexnet = np.argmax(alexnet_model.predict(X_test), axis=1)
y_pred_mobilenet = np.argmax(mobilenet_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Plot 10 random images with both predictions
plt.figure(figsize=(20, 10))
for i in range(10):
    idx = random.randint(0, len(X_test) - 1)
    img = X_test[idx]
    true_label = int(y_true[idx])
    pred_alex = int(y_pred_alexnet[idx])
    pred_mobilenet = int(y_pred_mobilenet[idx])

    plt.subplot(2, 5, i + 1)
    plt.imshow(img.astype("uint8"))
    title = f"True: {class_names[true_label]}\nAlexNet: {class_names[pred_alex]}\nMobileNet: {class_names[pred_mobilenet]}"
    color = "green" if (pred_alex == true_label and pred_mobilenet == true_label) else "red"
    plt.title(title, color=color, fontsize=10)
    plt.axis('off')

plt.tight_layout()
plt.savefig("alexnet_vs_mobilenet_predictions.png")
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 382ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 13s 579ms/step

# %%
y_pred_alexnet = np.argmax(alexnet_model.predict(X_test), axis=1)
y_pred_mobilenet = np.argmax(mobilenet_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 12s 564ms/step

# %%
import matplotlib.pyplot as plt
import random

class_names = ['Original', '3→5', '3→1', '3→2']  # Adjust to match your mapping

plt.figure(figsize=(18, 6))
for i in range(10):
    idx = random.randint(0, len(X_test) - 1)
    img = X_test[idx]
    true_label = y_true[idx]
    pred_alex = y_pred_alexnet[idx]
    pred_mobile = y_pred_mobilenet[idx]

    plt.subplot(2, 5, i + 1)
    plt.imshow(img)
    title = f"True: {class_names[true_label]}\nAlex: {class_names[pred_alex]}\nMobile: {class_names[pred_mobile]}"
    color = "green" if pred_alex == pred_mobile == true_label else "red"
    plt.title(title, color=color)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
print(val_generator_no_shuffle.class_indices)
# Out:
# {'class_0': 0, 'class_1': 1, 'class_2': 2, 'class_3': 3}

# %%
class_names = ['Original', '3→1', '3→2', '3→5']  # based on confirmed order

# Get predictions
y_pred_alexnet = np.argmax(alexnet_model.predict(X_test), axis=1)
y_pred_mobilenet = np.argmax(mobilenet_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Visualize 10 random predictions
plt.figure(figsize=(18, 6))
for i in range(10):
    idx = random.randint(0, len(X_test) - 1)
    img = X_test[idx]
    true_label = y_true[idx]
    pred_alex = y_pred_alexnet[idx]
    pred_mobile = y_pred_mobilenet[idx]

    plt.subplot(2, 5, i + 1)
    plt.imshow(img)
    plt.title(
        f"True: {class_names[true_label]}\nAlex: {class_names[pred_alex]}\nMobile: {class_names[pred_mobile]}",
        color="green" if true_label == pred_alex == pred_mobile else "red"
    )
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 559ms/step

# %%
class_names = ['Original', '3→1', '3→2', '3→5']  # based on confirmed order

# Get predictions
y_pred_alexnet = np.argmax(alexnet_model.predict(X_test), axis=1)
y_pred_mobilenet = np.argmax(mobilenet_model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Visualize 10 random predictions
plt.figure(figsize=(18, 6))
for i in range(10):
    idx = random.randint(0, len(X_test) - 1)
    img = X_test[idx]
    true_label = y_true[idx]
    pred_alex = y_pred_alexnet[idx]
    pred_mobile = y_pred_mobilenet[idx]

    plt.subplot(2, 5, i + 1)
    plt.imshow(img)
    plt.title(
        f"True: {class_names[true_label]}\nAlex: {class_names[pred_alex]}\nMobile: {class_names[pred_mobile]}",
        color="green" if true_label == pred_alex == pred_mobile else "red"
    )
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-39-1293553202.py in <cell line: 0>()
#       2
#       3 # Get predictions
# ----> 4 y_pred_alexnet = np.argmax(alexnet_model.predict(X_test), axis=1)
#       5 y_pred_mobilenet = np.argmax(mobilenet_model.predict(X_test), axis=1)
#       6 y_true = np.argmax(y_test, axis=1)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/array_data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps, shuffle, class_weight)
#      77
#      78         data_adapter_utils.check_data_cardinality(inputs)
# ---> 79         num_samples = set(i.shape[0] for i in tree.flatten(inputs)).pop()
#      80         self._num_samples = num_samples
#      81         self._inputs = inputs
#
# KeyError: 'pop from an empty set'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

val_dir = "/content/present_buckets_split/val"

datagen = ImageDataGenerator(rescale=1./255)

val_generator_no_shuffle = datagen.flow_from_directory(
    val_dir,
    target_size=(32, 32),
    batch_size=128,
    class_mode='categorical',
    shuffle=False
)

# Extract all validation images and labels
X_test, y_test = [], []

for _ in range(len(val_generator_no_shuffle)):
    x_batch, y_batch = val_generator_no_shuffle.next()
    X_test.extend(x_batch)
    y_test.extend(y_batch)

X_test = np.array(X_test)
y_test = np.array(y_test)
# Out:
# Found 40000 images belonging to 4 classes.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-33-561629416.py in <cell line: 0>()
#      18
#      19 for _ in range(len(val_generator_no_shuffle)):
# ---> 20     x_batch, y_batch = val_generator_no_shuffle.next()
#      21     X_test.extend(x_batch)
#      22     y_test.extend(y_batch)
#
# AttributeError: 'DirectoryIterator' object has no attribute 'next'

# %%
# !unzip "/content/drive/MyDrive/Present_cipher_project/present_original.zip" -d /content/original_unzipped
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/original_unzipped/train_encrypted_41436.png
#   inflating: /content/original_unzipped/train_encrypted_42587.png
#   inflating: /content/original_unzipped/train_encrypted_29398.png
#   inflating: /content/original_unzipped/train_encrypted_11309.png
#   inflating: /content/original_unzipped/train_encrypted_7250.png
#   inflating: /content/original_unzipped/train_encrypted_7091.png
#   inflating: /content/original_unzipped/train_encrypted_13879.png
#   inflating: /content/original_unzipped/train_encrypted_42440.png
